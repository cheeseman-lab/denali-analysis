# %% [markdown]
# # Configure Aggregate Module Params
#
# This notebook should be used as a test for ensuring correct aggregate parameters before aggregate processing.
# Cells marked with <font color='red'>SET PARAMETERS</font> contain crucial variables that need to be set according to your specific experimental setup and data organization.
# Please review and modify these variables as needed before proceeding with the analysis.

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Fixed parameters for aggregate module
#
# - `CONFIG_FILE_PATH`: Path to a Brieflow config file used during processing. Absolute or relative to where workflows are run from.

# %%
CONFIG_FILE_PATH = "config/config.yml"

# %%
from pathlib import Path
from itertools import product
import random

import yaml
import pandas as pd
import matplotlib.pyplot as plt

from lib.shared.file_utils import get_filename, load_parquet_subset
from lib.aggregate.cell_data_utils import split_cell_data, channel_combo_subset
from lib.aggregate.cell_classification import CellClassifier
from lib.aggregate.montage_utils import create_cell_montage, add_filenames
from lib.aggregate.filter import (
    query_filter,
    perturbation_filter,
    missing_values_filter,
    intensity_filter,
)
from lib.aggregate.align import (
    prepare_alignment_data,
    pca_variance_plot,
    embed_by_pca,
    tvn_on_controls,
)
from lib.aggregate.aggregate import aggregate
from lib.aggregate.eval_aggregate import (
    nas_summary,
    summarize_cell_data,
    plot_feature_distributions,
)
from lib.shared.configuration_utils import CONFIG_FILE_HEADER

random.seed(42)

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Testing on subset of data
#
# - `TEST_PLATE`: Plate used for testing configuration
# - `TEST_WELL_1`: First well identifier used for testing configuration
# - `TEST_WELL_2`: Second well identifier used for testing configuration

# %%
TEST_PLATE = 1
TEST_WELL_1 = "A1"
TEST_WELL_2 = "A2"

# %%
# load config file and determine root path
with open(CONFIG_FILE_PATH, "r") as config_file:
    config = yaml.safe_load(config_file)
ROOT_FP = Path(config["all"]["root_fp"])

# Load subset of data
# Takes ~1 minute
merge_final_fp = (
    ROOT_FP
    / "merge"
    / "parquets"
    / get_filename({"plate": TEST_PLATE, "well": TEST_WELL_1}, "merge_final", "parquet")
)
cell_data = load_parquet_subset(merge_final_fp, n_rows=25000)

merge_final_fp_2 = (
    ROOT_FP
    / "merge"
    / "parquets"
    / get_filename({"plate": TEST_PLATE, "well": TEST_WELL_2}, "merge_final", "parquet")
)
cell_data_2 = load_parquet_subset(merge_final_fp_2, n_rows=25000)

cell_data = pd.concat([cell_data, cell_data_2], ignore_index=True)
cell_data
# Out:
# Reading first 25,000 rows from brieflow_output/merge/parquets/P-1_W-A1__merge_final.parquet
# Reading first 25,000 rows from brieflow_output/merge/parquets/P-1_W-A2__merge_final.parquet
#        plate well  tile  cell_0          i_0          j_0  site  cell_1  \
# 0          1   A1  1045     438  1478.403947  1481.714474   243     265
# 1          1   A1   401     494  1477.766431  1478.877654   101     302
# 2          1   A1  1502     507  1480.628283  1477.384343   354     282
# 3          1   A1   595     482  1480.676399  1482.874696   154     228
# 4          1   A1  1479     613  1477.695030  1481.850904   365     360
# ...      ...  ...   ...     ...          ...          ...   ...     ...
# 49995      1   A2  1266     489  1420.418016  1664.271255   305     198
# 49996      1   A2  1182     677  1520.975945  1290.717526   302     365
# 49997      1   A2  1234     424  1511.256988  1671.142081   290    1781
# 49998      1   A2   765     431  1571.396514  1650.772876   192     248
# 49999      1   A2  1306     537  1591.093674  1321.326642   318    1966
#
#               i_1         j_1  ...  cytoplasm_zernike_9_1  \
# 0      100.072917  670.520833  ...               0.074622
# 1      100.089552  669.910448  ...               0.075236
# 2      100.674419   99.806202  ...               0.130661
# 3      100.764706  670.764706  ...               0.200692
# 4       99.273810  671.380952  ...               0.195139
# ...           ...         ...  ...                    ...
# 49995   84.565217  717.318841  ...               0.204233
# 49996  109.670588   52.788235  ...               0.131995
# 49997  678.524390  719.500000  ...               0.040305
# 49998  122.725000  713.541667  ...               0.048048
# 49999  700.198020   61.693069  ...               0.047520
#
#        cytoplasm_zernike_9_3  cytoplasm_zernike_9_5 cytoplasm_zernike_9_7  \
# 0                   0.120079               0.106608              0.043195
# 1                   0.016084               0.022822              0.033249
# 2                   0.127964               0.029040              0.006776
# 3                   0.058719               0.026384              0.011026
# 4                   0.024621               0.102549              0.077403
# ...                      ...                    ...                   ...
# 49995               0.195177               0.077798              0.028220
# 49996               0.107407               0.174412              0.075434
# 49997               0.051572               0.076769              0.061677
# 49998               0.161640               0.054195              0.043290
# 49999               0.177541               0.075033              0.012954
#
#       cytoplasm_zernike_9_9 cytoplasm_number_neighbors_1  \
# 0                  0.059320                            0
# 1                  0.008095                            1
# 2                  0.012450                            0
# 3                  0.016833                            2
# 4                  0.025830                            0
# ...                     ...                          ...
# 49995              0.011759                            0
# 49996              0.020633                            0
# 49997              0.025688                            1
# 49998              0.011734                            0
# 49999              0.038279                            0
#
#        cytoplasm_percent_touching_1  cytoplasm_first_neighbor_distance  \
# 0                          0.000000                          48.615252
# 1                          0.037791                          40.275758
# 2                          0.000000                          52.963143
# 3                          0.068627                          38.735022
# 4                          0.000000                          62.404446
# ...                             ...                                ...
# 49995                      0.000000                          68.133456
# 49996                      0.000000                          76.360067
# 49997                      0.103365                          51.946855
# 49998                      0.000000                          89.306692
# 49999                      0.000000                          78.079100
#
#        cytoplasm_second_neighbor_distance  cytoplasm_angle_between_neighbors
# 0                               55.257173                         159.483845
# 1                               56.068075                         115.752777
# 2                               70.225474                         167.657553
# 3                               47.030219                         157.402576
# 4                               63.974515                         134.672172
# ...                                   ...                                ...
# 49995                           84.498758                         169.942383
# 49996                           79.143785                         123.722519
# 49997                           56.660722                         158.502934
# 49998                          106.507049                          30.410540
# 49999                           85.789058                          45.775893
#
# [50000 rows x 1684 columns]

# %%
for col in cell_data.columns:
    print(col)
# Out:
# plate
# well
# tile
# cell_0
# i_0
# j_0
# site
# cell_1
# i_1
# j_1
# distance
# fov_distance_0
# fov_distance_1
# sgRNA_0
# gene_symbol_0
# mapped_single_gene
# channels_min
# nucleus_i
# nucleus_j
# nucleus_bounds_0
# nucleus_bounds_1
# nucleus_bounds_2
# nucleus_bounds_3
# cell_i
# cell_j
# cell_bounds_0
# cell_bounds_1
# cell_bounds_2
# cell_bounds_3
# cytoplasm_i
# cytoplasm_j
# cytoplasm_bounds_0
# cytoplasm_bounds_1
# cytoplasm_bounds_2
# cytoplasm_bounds_3
# nucleus_DAPI_int
# nucleus_COXIV_int
# nucleus_CENPA_int
# nucleus_WGA_int
# nucleus_DAPI_mean
# nucleus_COXIV_mean
# nucleus_CENPA_mean
# nucleus_WGA_mean
# nucleus_DAPI_std
# nucleus_COXIV_std
# nucleus_CENPA_std
# nucleus_WGA_std
# nucleus_DAPI_max
# nucleus_COXIV_max
# nucleus_CENPA_max
# nucleus_WGA_max
# nucleus_DAPI_min
# nucleus_COXIV_min
# nucleus_CENPA_min
# nucleus_WGA_min
# nucleus_DAPI_int_edge
# nucleus_COXIV_int_edge
# nucleus_CENPA_int_edge
# nucleus_WGA_int_edge
# nucleus_DAPI_mean_edge
# nucleus_COXIV_mean_edge
# nucleus_CENPA_mean_edge
# nucleus_WGA_mean_edge
# nucleus_DAPI_std_edge
# nucleus_COXIV_std_edge
# nucleus_CENPA_std_edge
# nucleus_WGA_std_edge
# nucleus_DAPI_max_edge
# nucleus_COXIV_max_edge
# nucleus_CENPA_max_edge
# nucleus_WGA_max_edge
# nucleus_DAPI_min_edge
# nucleus_COXIV_min_edge
# nucleus_CENPA_min_edge
# nucleus_WGA_min_edge
# nucleus_DAPI_mass_displacement
# nucleus_COXIV_mass_displacement
# nucleus_CENPA_mass_displacement
# nucleus_WGA_mass_displacement
# nucleus_DAPI_lower_quartile
# nucleus_COXIV_lower_quartile
# nucleus_CENPA_lower_quartile
# nucleus_WGA_lower_quartile
# nucleus_DAPI_median
# nucleus_COXIV_median
# nucleus_CENPA_median
# nucleus_WGA_median
# nucleus_DAPI_mad
# nucleus_COXIV_mad
# nucleus_CENPA_mad
# nucleus_WGA_mad
# nucleus_DAPI_upper_quartile
# nucleus_COXIV_upper_quartile
# nucleus_CENPA_upper_quartile
# nucleus_WGA_upper_quartile
# nucleus_DAPI_center_mass_r
# nucleus_COXIV_center_mass_r
# nucleus_CENPA_center_mass_r
# nucleus_WGA_center_mass_r
# nucleus_DAPI_center_mass_c
# nucleus_COXIV_center_mass_c
# nucleus_CENPA_center_mass_c
# nucleus_WGA_center_mass_c
# nucleus_DAPI_max_location_r
# nucleus_COXIV_max_location_r
# nucleus_CENPA_max_location_r
# nucleus_WGA_max_location_r
# nucleus_DAPI_max_location_c
# nucleus_COXIV_max_location_c
# nucleus_CENPA_max_location_c
# nucleus_WGA_max_location_c
# nucleus_DAPI_frac_at_d_0
# nucleus_COXIV_frac_at_d_0
# nucleus_CENPA_frac_at_d_0
# nucleus_WGA_frac_at_d_0
# nucleus_DAPI_frac_at_d_1
# nucleus_COXIV_frac_at_d_1
# nucleus_CENPA_frac_at_d_1
# nucleus_WGA_frac_at_d_1
# nucleus_DAPI_frac_at_d_2
# nucleus_COXIV_frac_at_d_2
# nucleus_CENPA_frac_at_d_2
# nucleus_WGA_frac_at_d_2
# nucleus_DAPI_frac_at_d_3
# nucleus_COXIV_frac_at_d_3
# nucleus_CENPA_frac_at_d_3
# nucleus_WGA_frac_at_d_3
# nucleus_DAPI_mean_frac_0
# nucleus_COXIV_mean_frac_0
# nucleus_CENPA_mean_frac_0
# nucleus_WGA_mean_frac_0
# nucleus_DAPI_mean_frac_1
# nucleus_COXIV_mean_frac_1
# nucleus_CENPA_mean_frac_1
# nucleus_WGA_mean_frac_1
# nucleus_DAPI_mean_frac_2
# nucleus_COXIV_mean_frac_2
# nucleus_CENPA_mean_frac_2
# nucleus_WGA_mean_frac_2
# nucleus_DAPI_mean_frac_3
# nucleus_COXIV_mean_frac_3
# nucleus_CENPA_mean_frac_3
# nucleus_WGA_mean_frac_3
# nucleus_DAPI_radial_cv_0
# nucleus_COXIV_radial_cv_0
# nucleus_CENPA_radial_cv_0
# nucleus_WGA_radial_cv_0
# nucleus_DAPI_radial_cv_1
# nucleus_COXIV_radial_cv_1
# nucleus_CENPA_radial_cv_1
# nucleus_WGA_radial_cv_1
# nucleus_DAPI_radial_cv_2
# nucleus_COXIV_radial_cv_2
# nucleus_CENPA_radial_cv_2
# nucleus_WGA_radial_cv_2
# nucleus_DAPI_radial_cv_3
# nucleus_COXIV_radial_cv_3
# nucleus_CENPA_radial_cv_3
# nucleus_WGA_radial_cv_3
# nucleus_DAPI_weighted_hu_moments_0
# nucleus_COXIV_weighted_hu_moments_0
# nucleus_CENPA_weighted_hu_moments_0
# nucleus_WGA_weighted_hu_moments_0
# nucleus_DAPI_weighted_hu_moments_1
# nucleus_COXIV_weighted_hu_moments_1
# nucleus_CENPA_weighted_hu_moments_1
# nucleus_WGA_weighted_hu_moments_1
# nucleus_DAPI_weighted_hu_moments_2
# nucleus_COXIV_weighted_hu_moments_2
# nucleus_CENPA_weighted_hu_moments_2
# nucleus_WGA_weighted_hu_moments_2
# nucleus_DAPI_weighted_hu_moments_3
# nucleus_COXIV_weighted_hu_moments_3
# nucleus_CENPA_weighted_hu_moments_3
# nucleus_WGA_weighted_hu_moments_3
# nucleus_DAPI_weighted_hu_moments_4
# nucleus_COXIV_weighted_hu_moments_4
# nucleus_CENPA_weighted_hu_moments_4
# nucleus_WGA_weighted_hu_moments_4
# nucleus_DAPI_weighted_hu_moments_5
# nucleus_COXIV_weighted_hu_moments_5
# nucleus_CENPA_weighted_hu_moments_5
# nucleus_WGA_weighted_hu_moments_5
# nucleus_DAPI_weighted_hu_moments_6
# nucleus_COXIV_weighted_hu_moments_6
# nucleus_CENPA_weighted_hu_moments_6
# nucleus_WGA_weighted_hu_moments_6
# nucleus_DAPI_pftas_0
# nucleus_COXIV_pftas_0
# nucleus_CENPA_pftas_0
# nucleus_WGA_pftas_0
# nucleus_DAPI_pftas_1
# nucleus_COXIV_pftas_1
# nucleus_CENPA_pftas_1
# nucleus_WGA_pftas_1
# nucleus_DAPI_pftas_2
# nucleus_COXIV_pftas_2
# nucleus_CENPA_pftas_2
# nucleus_WGA_pftas_2
# nucleus_DAPI_pftas_3
# nucleus_COXIV_pftas_3
# nucleus_CENPA_pftas_3
# nucleus_WGA_pftas_3
# nucleus_DAPI_pftas_4
# nucleus_COXIV_pftas_4
# nucleus_CENPA_pftas_4
# nucleus_WGA_pftas_4
# nucleus_DAPI_pftas_5
# nucleus_COXIV_pftas_5
# nucleus_CENPA_pftas_5
# nucleus_WGA_pftas_5
# nucleus_DAPI_pftas_6
# nucleus_COXIV_pftas_6
# nucleus_CENPA_pftas_6
# nucleus_WGA_pftas_6
# nucleus_DAPI_pftas_7
# nucleus_COXIV_pftas_7
# nucleus_CENPA_pftas_7
# nucleus_WGA_pftas_7
# nucleus_DAPI_pftas_8
# nucleus_COXIV_pftas_8
# nucleus_CENPA_pftas_8
# nucleus_WGA_pftas_8
# nucleus_DAPI_pftas_9
# nucleus_COXIV_pftas_9
# nucleus_CENPA_pftas_9
# nucleus_WGA_pftas_9
# nucleus_DAPI_pftas_10
# nucleus_COXIV_pftas_10
# nucleus_CENPA_pftas_10
# nucleus_WGA_pftas_10
# nucleus_DAPI_pftas_11
# nucleus_COXIV_pftas_11
# nucleus_CENPA_pftas_11
# nucleus_WGA_pftas_11
# nucleus_DAPI_pftas_12
# nucleus_COXIV_pftas_12
# nucleus_CENPA_pftas_12
# nucleus_WGA_pftas_12
# nucleus_DAPI_pftas_13
# nucleus_COXIV_pftas_13
# nucleus_CENPA_pftas_13
# nucleus_WGA_pftas_13
# nucleus_DAPI_pftas_14
# nucleus_COXIV_pftas_14
# nucleus_CENPA_pftas_14
# nucleus_WGA_pftas_14
# nucleus_DAPI_pftas_15
# nucleus_COXIV_pftas_15
# nucleus_CENPA_pftas_15
# nucleus_WGA_pftas_15
# nucleus_DAPI_pftas_16
# nucleus_COXIV_pftas_16
# nucleus_CENPA_pftas_16
# nucleus_WGA_pftas_16
# nucleus_DAPI_pftas_17
# nucleus_COXIV_pftas_17
# nucleus_CENPA_pftas_17
# nucleus_WGA_pftas_17
# nucleus_DAPI_pftas_18
# nucleus_COXIV_pftas_18
# nucleus_CENPA_pftas_18
# nucleus_WGA_pftas_18
# nucleus_DAPI_pftas_19
# nucleus_COXIV_pftas_19
# nucleus_CENPA_pftas_19
# nucleus_WGA_pftas_19
# nucleus_DAPI_pftas_20
# nucleus_COXIV_pftas_20
# nucleus_CENPA_pftas_20
# nucleus_WGA_pftas_20
# nucleus_DAPI_pftas_21
# nucleus_COXIV_pftas_21
# nucleus_CENPA_pftas_21
# nucleus_WGA_pftas_21
# nucleus_DAPI_pftas_22
# nucleus_COXIV_pftas_22
# nucleus_CENPA_pftas_22
# nucleus_WGA_pftas_22
# nucleus_DAPI_pftas_23
# nucleus_COXIV_pftas_23
# nucleus_CENPA_pftas_23
# nucleus_WGA_pftas_23
# nucleus_DAPI_pftas_24
# nucleus_COXIV_pftas_24
# nucleus_CENPA_pftas_24
# nucleus_WGA_pftas_24
# nucleus_DAPI_pftas_25
# nucleus_COXIV_pftas_25
# nucleus_CENPA_pftas_25
# nucleus_WGA_pftas_25
# nucleus_DAPI_pftas_26
# nucleus_COXIV_pftas_26
# nucleus_CENPA_pftas_26
# nucleus_WGA_pftas_26
# nucleus_DAPI_pftas_27
# nucleus_COXIV_pftas_27
# nucleus_CENPA_pftas_27
# nucleus_WGA_pftas_27
# nucleus_DAPI_pftas_28
# nucleus_COXIV_pftas_28
# nucleus_CENPA_pftas_28
# nucleus_WGA_pftas_28
# nucleus_DAPI_pftas_29
# nucleus_COXIV_pftas_29
# nucleus_CENPA_pftas_29
# nucleus_WGA_pftas_29
# nucleus_DAPI_pftas_30
# nucleus_COXIV_pftas_30
# nucleus_CENPA_pftas_30
# nucleus_WGA_pftas_30
# nucleus_DAPI_pftas_31
# nucleus_COXIV_pftas_31
# nucleus_CENPA_pftas_31
# nucleus_WGA_pftas_31
# nucleus_DAPI_pftas_32
# nucleus_COXIV_pftas_32
# nucleus_CENPA_pftas_32
# nucleus_WGA_pftas_32
# nucleus_DAPI_pftas_33
# nucleus_COXIV_pftas_33
# nucleus_CENPA_pftas_33
# nucleus_WGA_pftas_33
# nucleus_DAPI_pftas_34
# nucleus_COXIV_pftas_34
# nucleus_CENPA_pftas_34
# nucleus_WGA_pftas_34
# nucleus_DAPI_pftas_35
# nucleus_COXIV_pftas_35
# nucleus_CENPA_pftas_35
# nucleus_WGA_pftas_35
# nucleus_DAPI_pftas_36
# nucleus_COXIV_pftas_36
# nucleus_CENPA_pftas_36
# nucleus_WGA_pftas_36
# nucleus_DAPI_pftas_37
# nucleus_COXIV_pftas_37
# nucleus_CENPA_pftas_37
# nucleus_WGA_pftas_37
# nucleus_DAPI_pftas_38
# nucleus_COXIV_pftas_38
# nucleus_CENPA_pftas_38
# nucleus_WGA_pftas_38
# nucleus_DAPI_pftas_39
# nucleus_COXIV_pftas_39
# nucleus_CENPA_pftas_39
# nucleus_WGA_pftas_39
# nucleus_DAPI_pftas_40
# nucleus_COXIV_pftas_40
# nucleus_CENPA_pftas_40
# nucleus_WGA_pftas_40
# nucleus_DAPI_pftas_41
# nucleus_COXIV_pftas_41
# nucleus_CENPA_pftas_41
# nucleus_WGA_pftas_41
# nucleus_DAPI_pftas_42
# nucleus_COXIV_pftas_42
# nucleus_CENPA_pftas_42
# nucleus_WGA_pftas_42
# nucleus_DAPI_pftas_43
# nucleus_COXIV_pftas_43
# nucleus_CENPA_pftas_43
# nucleus_WGA_pftas_43
# nucleus_DAPI_pftas_44
# nucleus_COXIV_pftas_44
# nucleus_CENPA_pftas_44
# nucleus_WGA_pftas_44
# nucleus_DAPI_pftas_45
# nucleus_COXIV_pftas_45
# nucleus_CENPA_pftas_45
# nucleus_WGA_pftas_45
# nucleus_DAPI_pftas_46
# nucleus_COXIV_pftas_46
# nucleus_CENPA_pftas_46
# nucleus_WGA_pftas_46
# nucleus_DAPI_pftas_47
# nucleus_COXIV_pftas_47
# nucleus_CENPA_pftas_47
# nucleus_WGA_pftas_47
# nucleus_DAPI_pftas_48
# nucleus_COXIV_pftas_48
# nucleus_CENPA_pftas_48
# nucleus_WGA_pftas_48
# nucleus_DAPI_pftas_49
# nucleus_COXIV_pftas_49
# nucleus_CENPA_pftas_49
# nucleus_WGA_pftas_49
# nucleus_DAPI_pftas_50
# nucleus_COXIV_pftas_50
# nucleus_CENPA_pftas_50
# nucleus_WGA_pftas_50
# nucleus_DAPI_pftas_51
# nucleus_COXIV_pftas_51
# nucleus_CENPA_pftas_51
# nucleus_WGA_pftas_51
# nucleus_DAPI_pftas_52
# nucleus_COXIV_pftas_52
# nucleus_CENPA_pftas_52
# nucleus_WGA_pftas_52
# nucleus_DAPI_pftas_53
# nucleus_COXIV_pftas_53
# nucleus_CENPA_pftas_53
# nucleus_WGA_pftas_53
# nucleus_DAPI_haralick_5_0
# nucleus_COXIV_haralick_5_0
# nucleus_CENPA_haralick_5_0
# nucleus_WGA_haralick_5_0
# nucleus_DAPI_haralick_5_1
# nucleus_COXIV_haralick_5_1
# nucleus_CENPA_haralick_5_1
# nucleus_WGA_haralick_5_1
# nucleus_DAPI_haralick_5_2
# nucleus_COXIV_haralick_5_2
# nucleus_CENPA_haralick_5_2
# nucleus_WGA_haralick_5_2
# nucleus_DAPI_haralick_5_3
# nucleus_COXIV_haralick_5_3
# nucleus_CENPA_haralick_5_3
# nucleus_WGA_haralick_5_3
# nucleus_DAPI_haralick_5_4
# nucleus_COXIV_haralick_5_4
# nucleus_CENPA_haralick_5_4
# nucleus_WGA_haralick_5_4
# nucleus_DAPI_haralick_5_5
# nucleus_COXIV_haralick_5_5
# nucleus_CENPA_haralick_5_5
# nucleus_WGA_haralick_5_5
# nucleus_DAPI_haralick_5_6
# nucleus_COXIV_haralick_5_6
# nucleus_CENPA_haralick_5_6
# nucleus_WGA_haralick_5_6
# nucleus_DAPI_haralick_5_7
# nucleus_COXIV_haralick_5_7
# nucleus_CENPA_haralick_5_7
# nucleus_WGA_haralick_5_7
# nucleus_DAPI_haralick_5_8
# nucleus_COXIV_haralick_5_8
# nucleus_CENPA_haralick_5_8
# nucleus_WGA_haralick_5_8
# nucleus_DAPI_haralick_5_9
# nucleus_COXIV_haralick_5_9
# nucleus_CENPA_haralick_5_9
# nucleus_WGA_haralick_5_9
# nucleus_DAPI_haralick_5_10
# nucleus_COXIV_haralick_5_10
# nucleus_CENPA_haralick_5_10
# nucleus_WGA_haralick_5_10
# nucleus_DAPI_haralick_5_11
# nucleus_COXIV_haralick_5_11
# nucleus_CENPA_haralick_5_11
# nucleus_WGA_haralick_5_11
# nucleus_DAPI_haralick_5_12
# nucleus_COXIV_haralick_5_12
# nucleus_CENPA_haralick_5_12
# nucleus_WGA_haralick_5_12
# nucleus_correlation_DAPI_COXIV
# nucleus_correlation_DAPI_CENPA
# nucleus_correlation_DAPI_WGA
# nucleus_correlation_COXIV_CENPA
# nucleus_correlation_COXIV_WGA
# nucleus_correlation_CENPA_WGA
# nucleus_lstsq_slope_DAPI_COXIV
# nucleus_lstsq_slope_DAPI_CENPA
# nucleus_lstsq_slope_DAPI_WGA
# nucleus_lstsq_slope_COXIV_DAPI
# nucleus_lstsq_slope_COXIV_CENPA
# nucleus_lstsq_slope_COXIV_WGA
# nucleus_lstsq_slope_CENPA_DAPI
# nucleus_lstsq_slope_CENPA_COXIV
# nucleus_lstsq_slope_CENPA_WGA
# nucleus_lstsq_slope_WGA_DAPI
# nucleus_lstsq_slope_WGA_COXIV
# nucleus_lstsq_slope_WGA_CENPA
# nucleus_overlap_DAPI_COXIV
# nucleus_overlap_DAPI_CENPA
# nucleus_overlap_DAPI_WGA
# nucleus_overlap_COXIV_CENPA
# nucleus_overlap_COXIV_WGA
# nucleus_overlap_CENPA_WGA
# nucleus_K_DAPI_COXIV
# nucleus_K_DAPI_CENPA
# nucleus_K_DAPI_WGA
# nucleus_K_COXIV_CENPA
# nucleus_K_COXIV_WGA
# nucleus_K_CENPA_WGA
# nucleus_K_COXIV_DAPI
# nucleus_K_CENPA_DAPI
# nucleus_K_WGA_DAPI
# nucleus_K_CENPA_COXIV
# nucleus_K_WGA_COXIV
# nucleus_K_WGA_CENPA
# nucleus_manders_DAPI_COXIV
# nucleus_manders_DAPI_CENPA
# nucleus_manders_DAPI_WGA
# nucleus_manders_COXIV_CENPA
# nucleus_manders_COXIV_WGA
# nucleus_manders_CENPA_WGA
# nucleus_manders_COXIV_DAPI
# nucleus_manders_CENPA_DAPI
# nucleus_manders_WGA_DAPI
# nucleus_manders_CENPA_COXIV
# nucleus_manders_WGA_COXIV
# nucleus_manders_WGA_CENPA
# nucleus_rwc_DAPI_COXIV
# nucleus_rwc_DAPI_CENPA
# nucleus_rwc_DAPI_WGA
# nucleus_rwc_COXIV_CENPA
# nucleus_rwc_COXIV_WGA
# nucleus_rwc_CENPA_WGA
# nucleus_rwc_COXIV_DAPI
# nucleus_rwc_CENPA_DAPI
# nucleus_rwc_WGA_DAPI
# nucleus_rwc_CENPA_COXIV
# nucleus_rwc_WGA_COXIV
# nucleus_rwc_WGA_CENPA
# nucleus_area
# nucleus_perimeter
# nucleus_convex_area
# nucleus_form_factor
# nucleus_solidity
# nucleus_extent
# nucleus_euler_number
# nucleus_centroid_r
# nucleus_centroid_c
# nucleus_eccentricity
# nucleus_major_axis
# nucleus_minor_axis
# nucleus_orientation
# nucleus_compactness
# nucleus_max_radius
# nucleus_median_radius
# nucleus_mean_radius
# nucleus_min_feret_diameter
# nucleus_max_feret_diameter
# nucleus_min_feret_r0
# nucleus_min_feret_c0
# nucleus_min_feret_r1
# nucleus_min_feret_c1
# nucleus_max_feret_r0
# nucleus_max_feret_c0
# nucleus_max_feret_r1
# nucleus_max_feret_c1
# nucleus_hu_moments_0
# nucleus_hu_moments_1
# nucleus_hu_moments_2
# nucleus_hu_moments_3
# nucleus_hu_moments_4
# nucleus_hu_moments_5
# nucleus_hu_moments_6
# nucleus_zernike_0_0
# nucleus_zernike_1_1
# nucleus_zernike_2_0
# nucleus_zernike_2_2
# nucleus_zernike_3_1
# nucleus_zernike_3_3
# nucleus_zernike_4_0
# nucleus_zernike_4_2
# nucleus_zernike_4_4
# nucleus_zernike_5_1
# nucleus_zernike_5_3
# nucleus_zernike_5_5
# nucleus_zernike_6_0
# nucleus_zernike_6_2
# nucleus_zernike_6_4
# nucleus_zernike_6_6
# nucleus_zernike_7_1
# nucleus_zernike_7_3
# nucleus_zernike_7_5
# nucleus_zernike_7_7
# nucleus_zernike_8_0
# nucleus_zernike_8_2
# nucleus_zernike_8_4
# nucleus_zernike_8_6
# nucleus_zernike_8_8
# nucleus_zernike_9_1
# nucleus_zernike_9_3
# nucleus_zernike_9_5
# nucleus_zernike_9_7
# nucleus_zernike_9_9
# nucleus_number_neighbors_1
# nucleus_percent_touching_1
# nucleus_first_neighbor_distance
# nucleus_second_neighbor_distance
# nucleus_angle_between_neighbors
# cell_DAPI_int
# cell_COXIV_int
# cell_CENPA_int
# cell_WGA_int
# cell_DAPI_mean
# cell_COXIV_mean
# cell_CENPA_mean
# cell_WGA_mean
# cell_DAPI_std
# cell_COXIV_std
# cell_CENPA_std
# cell_WGA_std
# cell_DAPI_max
# cell_COXIV_max
# cell_CENPA_max
# cell_WGA_max
# cell_DAPI_min
# cell_COXIV_min
# cell_CENPA_min
# cell_WGA_min
# cell_DAPI_int_edge
# cell_COXIV_int_edge
# cell_CENPA_int_edge
# cell_WGA_int_edge
# cell_DAPI_mean_edge
# cell_COXIV_mean_edge
# cell_CENPA_mean_edge
# cell_WGA_mean_edge
# cell_DAPI_std_edge
# cell_COXIV_std_edge
# cell_CENPA_std_edge
# cell_WGA_std_edge
# cell_DAPI_max_edge
# cell_COXIV_max_edge
# cell_CENPA_max_edge
# cell_WGA_max_edge
# cell_DAPI_min_edge
# cell_COXIV_min_edge
# cell_CENPA_min_edge
# cell_WGA_min_edge
# cell_DAPI_mass_displacement
# cell_COXIV_mass_displacement
# cell_CENPA_mass_displacement
# cell_WGA_mass_displacement
# cell_DAPI_lower_quartile
# cell_COXIV_lower_quartile
# cell_CENPA_lower_quartile
# cell_WGA_lower_quartile
# cell_DAPI_median
# cell_COXIV_median
# cell_CENPA_median
# cell_WGA_median
# cell_DAPI_mad
# cell_COXIV_mad
# cell_CENPA_mad
# cell_WGA_mad
# cell_DAPI_upper_quartile
# cell_COXIV_upper_quartile
# cell_CENPA_upper_quartile
# cell_WGA_upper_quartile
# cell_DAPI_center_mass_r
# cell_COXIV_center_mass_r
# cell_CENPA_center_mass_r
# cell_WGA_center_mass_r
# cell_DAPI_center_mass_c
# cell_COXIV_center_mass_c
# cell_CENPA_center_mass_c
# cell_WGA_center_mass_c
# cell_DAPI_max_location_r
# cell_COXIV_max_location_r
# cell_CENPA_max_location_r
# cell_WGA_max_location_r
# cell_DAPI_max_location_c
# cell_COXIV_max_location_c
# cell_CENPA_max_location_c
# cell_WGA_max_location_c
# cell_DAPI_frac_at_d_0
# cell_COXIV_frac_at_d_0
# cell_CENPA_frac_at_d_0
# cell_WGA_frac_at_d_0
# cell_DAPI_frac_at_d_1
# cell_COXIV_frac_at_d_1
# cell_CENPA_frac_at_d_1
# cell_WGA_frac_at_d_1
# cell_DAPI_frac_at_d_2
# cell_COXIV_frac_at_d_2
# cell_CENPA_frac_at_d_2
# cell_WGA_frac_at_d_2
# cell_DAPI_frac_at_d_3
# cell_COXIV_frac_at_d_3
# cell_CENPA_frac_at_d_3
# cell_WGA_frac_at_d_3
# cell_DAPI_mean_frac_0
# cell_COXIV_mean_frac_0
# cell_CENPA_mean_frac_0
# cell_WGA_mean_frac_0
# cell_DAPI_mean_frac_1
# cell_COXIV_mean_frac_1
# cell_CENPA_mean_frac_1
# cell_WGA_mean_frac_1
# cell_DAPI_mean_frac_2
# cell_COXIV_mean_frac_2
# cell_CENPA_mean_frac_2
# cell_WGA_mean_frac_2
# cell_DAPI_mean_frac_3
# cell_COXIV_mean_frac_3
# cell_CENPA_mean_frac_3
# cell_WGA_mean_frac_3
# cell_DAPI_radial_cv_0
# cell_COXIV_radial_cv_0
# cell_CENPA_radial_cv_0
# cell_WGA_radial_cv_0
# cell_DAPI_radial_cv_1
# cell_COXIV_radial_cv_1
# cell_CENPA_radial_cv_1
# cell_WGA_radial_cv_1
# cell_DAPI_radial_cv_2
# cell_COXIV_radial_cv_2
# cell_CENPA_radial_cv_2
# cell_WGA_radial_cv_2
# cell_DAPI_radial_cv_3
# cell_COXIV_radial_cv_3
# cell_CENPA_radial_cv_3
# cell_WGA_radial_cv_3
# cell_DAPI_weighted_hu_moments_0
# cell_COXIV_weighted_hu_moments_0
# cell_CENPA_weighted_hu_moments_0
# cell_WGA_weighted_hu_moments_0
# cell_DAPI_weighted_hu_moments_1
# cell_COXIV_weighted_hu_moments_1
# cell_CENPA_weighted_hu_moments_1
# cell_WGA_weighted_hu_moments_1
# cell_DAPI_weighted_hu_moments_2
# cell_COXIV_weighted_hu_moments_2
# cell_CENPA_weighted_hu_moments_2
# cell_WGA_weighted_hu_moments_2
# cell_DAPI_weighted_hu_moments_3
# cell_COXIV_weighted_hu_moments_3
# cell_CENPA_weighted_hu_moments_3
# cell_WGA_weighted_hu_moments_3
# cell_DAPI_weighted_hu_moments_4
# cell_COXIV_weighted_hu_moments_4
# cell_CENPA_weighted_hu_moments_4
# cell_WGA_weighted_hu_moments_4
# cell_DAPI_weighted_hu_moments_5
# cell_COXIV_weighted_hu_moments_5
# cell_CENPA_weighted_hu_moments_5
# cell_WGA_weighted_hu_moments_5
# cell_DAPI_weighted_hu_moments_6
# cell_COXIV_weighted_hu_moments_6
# cell_CENPA_weighted_hu_moments_6
# cell_WGA_weighted_hu_moments_6
# cell_DAPI_pftas_0
# cell_COXIV_pftas_0
# cell_CENPA_pftas_0
# cell_WGA_pftas_0
# cell_DAPI_pftas_1
# cell_COXIV_pftas_1
# cell_CENPA_pftas_1
# cell_WGA_pftas_1
# cell_DAPI_pftas_2
# cell_COXIV_pftas_2
# cell_CENPA_pftas_2
# cell_WGA_pftas_2
# cell_DAPI_pftas_3
# cell_COXIV_pftas_3
# cell_CENPA_pftas_3
# cell_WGA_pftas_3
# cell_DAPI_pftas_4
# cell_COXIV_pftas_4
# cell_CENPA_pftas_4
# cell_WGA_pftas_4
# cell_DAPI_pftas_5
# cell_COXIV_pftas_5
# cell_CENPA_pftas_5
# cell_WGA_pftas_5
# cell_DAPI_pftas_6
# cell_COXIV_pftas_6
# cell_CENPA_pftas_6
# cell_WGA_pftas_6
# cell_DAPI_pftas_7
# cell_COXIV_pftas_7
# cell_CENPA_pftas_7
# cell_WGA_pftas_7
# cell_DAPI_pftas_8
# cell_COXIV_pftas_8
# cell_CENPA_pftas_8
# cell_WGA_pftas_8
# cell_DAPI_pftas_9
# cell_COXIV_pftas_9
# cell_CENPA_pftas_9
# cell_WGA_pftas_9
# cell_DAPI_pftas_10
# cell_COXIV_pftas_10
# cell_CENPA_pftas_10
# cell_WGA_pftas_10
# cell_DAPI_pftas_11
# cell_COXIV_pftas_11
# cell_CENPA_pftas_11
# cell_WGA_pftas_11
# cell_DAPI_pftas_12
# cell_COXIV_pftas_12
# cell_CENPA_pftas_12
# cell_WGA_pftas_12
# cell_DAPI_pftas_13
# cell_COXIV_pftas_13
# cell_CENPA_pftas_13
# cell_WGA_pftas_13
# cell_DAPI_pftas_14
# cell_COXIV_pftas_14
# cell_CENPA_pftas_14
# cell_WGA_pftas_14
# cell_DAPI_pftas_15
# cell_COXIV_pftas_15
# cell_CENPA_pftas_15
# cell_WGA_pftas_15
# cell_DAPI_pftas_16
# cell_COXIV_pftas_16
# cell_CENPA_pftas_16
# cell_WGA_pftas_16
# cell_DAPI_pftas_17
# cell_COXIV_pftas_17
# cell_CENPA_pftas_17
# cell_WGA_pftas_17
# cell_DAPI_pftas_18
# cell_COXIV_pftas_18
# cell_CENPA_pftas_18
# cell_WGA_pftas_18
# cell_DAPI_pftas_19
# cell_COXIV_pftas_19
# cell_CENPA_pftas_19
# cell_WGA_pftas_19
# cell_DAPI_pftas_20
# cell_COXIV_pftas_20
# cell_CENPA_pftas_20
# cell_WGA_pftas_20
# cell_DAPI_pftas_21
# cell_COXIV_pftas_21
# cell_CENPA_pftas_21
# cell_WGA_pftas_21
# cell_DAPI_pftas_22
# cell_COXIV_pftas_22
# cell_CENPA_pftas_22
# cell_WGA_pftas_22
# cell_DAPI_pftas_23
# cell_COXIV_pftas_23
# cell_CENPA_pftas_23
# cell_WGA_pftas_23
# cell_DAPI_pftas_24
# cell_COXIV_pftas_24
# cell_CENPA_pftas_24
# cell_WGA_pftas_24
# cell_DAPI_pftas_25
# cell_COXIV_pftas_25
# cell_CENPA_pftas_25
# cell_WGA_pftas_25
# cell_DAPI_pftas_26
# cell_COXIV_pftas_26
# cell_CENPA_pftas_26
# cell_WGA_pftas_26
# cell_DAPI_pftas_27
# cell_COXIV_pftas_27
# cell_CENPA_pftas_27
# cell_WGA_pftas_27
# cell_DAPI_pftas_28
# cell_COXIV_pftas_28
# cell_CENPA_pftas_28
# cell_WGA_pftas_28
# cell_DAPI_pftas_29
# cell_COXIV_pftas_29
# cell_CENPA_pftas_29
# cell_WGA_pftas_29
# cell_DAPI_pftas_30
# cell_COXIV_pftas_30
# cell_CENPA_pftas_30
# cell_WGA_pftas_30
# cell_DAPI_pftas_31
# cell_COXIV_pftas_31
# cell_CENPA_pftas_31
# cell_WGA_pftas_31
# cell_DAPI_pftas_32
# cell_COXIV_pftas_32
# cell_CENPA_pftas_32
# cell_WGA_pftas_32
# cell_DAPI_pftas_33
# cell_COXIV_pftas_33
# cell_CENPA_pftas_33
# cell_WGA_pftas_33
# cell_DAPI_pftas_34
# cell_COXIV_pftas_34
# cell_CENPA_pftas_34
# cell_WGA_pftas_34
# cell_DAPI_pftas_35
# cell_COXIV_pftas_35
# cell_CENPA_pftas_35
# cell_WGA_pftas_35
# cell_DAPI_pftas_36
# cell_COXIV_pftas_36
# cell_CENPA_pftas_36
# cell_WGA_pftas_36
# cell_DAPI_pftas_37
# cell_COXIV_pftas_37
# cell_CENPA_pftas_37
# cell_WGA_pftas_37
# cell_DAPI_pftas_38
# cell_COXIV_pftas_38
# cell_CENPA_pftas_38
# cell_WGA_pftas_38
# cell_DAPI_pftas_39
# cell_COXIV_pftas_39
# cell_CENPA_pftas_39
# cell_WGA_pftas_39
# cell_DAPI_pftas_40
# cell_COXIV_pftas_40
# cell_CENPA_pftas_40
# cell_WGA_pftas_40
# cell_DAPI_pftas_41
# cell_COXIV_pftas_41
# cell_CENPA_pftas_41
# cell_WGA_pftas_41
# cell_DAPI_pftas_42
# cell_COXIV_pftas_42
# cell_CENPA_pftas_42
# cell_WGA_pftas_42
# cell_DAPI_pftas_43
# cell_COXIV_pftas_43
# cell_CENPA_pftas_43
# cell_WGA_pftas_43
# cell_DAPI_pftas_44
# cell_COXIV_pftas_44
# cell_CENPA_pftas_44
# cell_WGA_pftas_44
# cell_DAPI_pftas_45
# cell_COXIV_pftas_45
# cell_CENPA_pftas_45
# cell_WGA_pftas_45
# cell_DAPI_pftas_46
# cell_COXIV_pftas_46
# cell_CENPA_pftas_46
# cell_WGA_pftas_46
# cell_DAPI_pftas_47
# cell_COXIV_pftas_47
# cell_CENPA_pftas_47
# cell_WGA_pftas_47
# cell_DAPI_pftas_48
# cell_COXIV_pftas_48
# cell_CENPA_pftas_48
# cell_WGA_pftas_48
# cell_DAPI_pftas_49
# cell_COXIV_pftas_49
# cell_CENPA_pftas_49
# cell_WGA_pftas_49
# cell_DAPI_pftas_50
# cell_COXIV_pftas_50
# cell_CENPA_pftas_50
# cell_WGA_pftas_50
# cell_DAPI_pftas_51
# cell_COXIV_pftas_51
# cell_CENPA_pftas_51
# cell_WGA_pftas_51
# cell_DAPI_pftas_52
# cell_COXIV_pftas_52
# cell_CENPA_pftas_52
# cell_WGA_pftas_52
# cell_DAPI_pftas_53
# cell_COXIV_pftas_53
# cell_CENPA_pftas_53
# cell_WGA_pftas_53
# cell_DAPI_haralick_5_0
# cell_COXIV_haralick_5_0
# cell_CENPA_haralick_5_0
# cell_WGA_haralick_5_0
# cell_DAPI_haralick_5_1
# cell_COXIV_haralick_5_1
# cell_CENPA_haralick_5_1
# cell_WGA_haralick_5_1
# cell_DAPI_haralick_5_2
# cell_COXIV_haralick_5_2
# cell_CENPA_haralick_5_2
# cell_WGA_haralick_5_2
# cell_DAPI_haralick_5_3
# cell_COXIV_haralick_5_3
# cell_CENPA_haralick_5_3
# cell_WGA_haralick_5_3
# cell_DAPI_haralick_5_4
# cell_COXIV_haralick_5_4
# cell_CENPA_haralick_5_4
# cell_WGA_haralick_5_4
# cell_DAPI_haralick_5_5
# cell_COXIV_haralick_5_5
# cell_CENPA_haralick_5_5
# cell_WGA_haralick_5_5
# cell_DAPI_haralick_5_6
# cell_COXIV_haralick_5_6
# cell_CENPA_haralick_5_6
# cell_WGA_haralick_5_6
# cell_DAPI_haralick_5_7
# cell_COXIV_haralick_5_7
# cell_CENPA_haralick_5_7
# cell_WGA_haralick_5_7
# cell_DAPI_haralick_5_8
# cell_COXIV_haralick_5_8
# cell_CENPA_haralick_5_8
# cell_WGA_haralick_5_8
# cell_DAPI_haralick_5_9
# cell_COXIV_haralick_5_9
# cell_CENPA_haralick_5_9
# cell_WGA_haralick_5_9
# cell_DAPI_haralick_5_10
# cell_COXIV_haralick_5_10
# cell_CENPA_haralick_5_10
# cell_WGA_haralick_5_10
# cell_DAPI_haralick_5_11
# cell_COXIV_haralick_5_11
# cell_CENPA_haralick_5_11
# cell_WGA_haralick_5_11
# cell_DAPI_haralick_5_12
# cell_COXIV_haralick_5_12
# cell_CENPA_haralick_5_12
# cell_WGA_haralick_5_12
# cell_correlation_DAPI_COXIV
# cell_correlation_DAPI_CENPA
# cell_correlation_DAPI_WGA
# cell_correlation_COXIV_CENPA
# cell_correlation_COXIV_WGA
# cell_correlation_CENPA_WGA
# cell_lstsq_slope_DAPI_COXIV
# cell_lstsq_slope_DAPI_CENPA
# cell_lstsq_slope_DAPI_WGA
# cell_lstsq_slope_COXIV_DAPI
# cell_lstsq_slope_COXIV_CENPA
# cell_lstsq_slope_COXIV_WGA
# cell_lstsq_slope_CENPA_DAPI
# cell_lstsq_slope_CENPA_COXIV
# cell_lstsq_slope_CENPA_WGA
# cell_lstsq_slope_WGA_DAPI
# cell_lstsq_slope_WGA_COXIV
# cell_lstsq_slope_WGA_CENPA
# cell_overlap_DAPI_COXIV
# cell_overlap_DAPI_CENPA
# cell_overlap_DAPI_WGA
# cell_overlap_COXIV_CENPA
# cell_overlap_COXIV_WGA
# cell_overlap_CENPA_WGA
# cell_K_DAPI_COXIV
# cell_K_DAPI_CENPA
# cell_K_DAPI_WGA
# cell_K_COXIV_CENPA
# cell_K_COXIV_WGA
# cell_K_CENPA_WGA
# cell_K_COXIV_DAPI
# cell_K_CENPA_DAPI
# cell_K_WGA_DAPI
# cell_K_CENPA_COXIV
# cell_K_WGA_COXIV
# cell_K_WGA_CENPA
# cell_manders_DAPI_COXIV
# cell_manders_DAPI_CENPA
# cell_manders_DAPI_WGA
# cell_manders_COXIV_CENPA
# cell_manders_COXIV_WGA
# cell_manders_CENPA_WGA
# cell_manders_COXIV_DAPI
# cell_manders_CENPA_DAPI
# cell_manders_WGA_DAPI
# cell_manders_CENPA_COXIV
# cell_manders_WGA_COXIV
# cell_manders_WGA_CENPA
# cell_rwc_DAPI_COXIV
# cell_rwc_DAPI_CENPA
# cell_rwc_DAPI_WGA
# cell_rwc_COXIV_CENPA
# cell_rwc_COXIV_WGA
# cell_rwc_CENPA_WGA
# cell_rwc_COXIV_DAPI
# cell_rwc_CENPA_DAPI
# cell_rwc_WGA_DAPI
# cell_rwc_CENPA_COXIV
# cell_rwc_WGA_COXIV
# cell_rwc_WGA_CENPA
# cell_area
# cell_perimeter
# cell_convex_area
# cell_form_factor
# cell_solidity
# cell_extent
# cell_euler_number
# cell_centroid_r
# cell_centroid_c
# cell_eccentricity
# cell_major_axis
# cell_minor_axis
# cell_orientation
# cell_compactness
# cell_max_radius
# cell_median_radius
# cell_mean_radius
# cell_min_feret_diameter
# cell_max_feret_diameter
# cell_min_feret_r0
# cell_min_feret_c0
# cell_min_feret_r1
# cell_min_feret_c1
# cell_max_feret_r0
# cell_max_feret_c0
# cell_max_feret_r1
# cell_max_feret_c1
# cell_hu_moments_0
# cell_hu_moments_1
# cell_hu_moments_2
# cell_hu_moments_3
# cell_hu_moments_4
# cell_hu_moments_5
# cell_hu_moments_6
# cell_zernike_0_0
# cell_zernike_1_1
# cell_zernike_2_0
# cell_zernike_2_2
# cell_zernike_3_1
# cell_zernike_3_3
# cell_zernike_4_0
# cell_zernike_4_2
# cell_zernike_4_4
# cell_zernike_5_1
# cell_zernike_5_3
# cell_zernike_5_5
# cell_zernike_6_0
# cell_zernike_6_2
# cell_zernike_6_4
# cell_zernike_6_6
# cell_zernike_7_1
# cell_zernike_7_3
# cell_zernike_7_5
# cell_zernike_7_7
# cell_zernike_8_0
# cell_zernike_8_2
# cell_zernike_8_4
# cell_zernike_8_6
# cell_zernike_8_8
# cell_zernike_9_1
# cell_zernike_9_3
# cell_zernike_9_5
# cell_zernike_9_7
# cell_zernike_9_9
# cell_CENPA_foci_count
# cell_CENPA_foci_area
# cell_number_neighbors_1
# cell_percent_touching_1
# cell_first_neighbor_distance
# cell_second_neighbor_distance
# cell_angle_between_neighbors
# cytoplasm_DAPI_int
# cytoplasm_COXIV_int
# cytoplasm_CENPA_int
# cytoplasm_WGA_int
# cytoplasm_DAPI_mean
# cytoplasm_COXIV_mean
# cytoplasm_CENPA_mean
# cytoplasm_WGA_mean
# cytoplasm_DAPI_std
# cytoplasm_COXIV_std
# cytoplasm_CENPA_std
# cytoplasm_WGA_std
# cytoplasm_DAPI_max
# cytoplasm_COXIV_max
# cytoplasm_CENPA_max
# cytoplasm_WGA_max
# cytoplasm_DAPI_min
# cytoplasm_COXIV_min
# cytoplasm_CENPA_min
# cytoplasm_WGA_min
# cytoplasm_DAPI_int_edge
# cytoplasm_COXIV_int_edge
# cytoplasm_CENPA_int_edge
# cytoplasm_WGA_int_edge
# cytoplasm_DAPI_mean_edge
# cytoplasm_COXIV_mean_edge
# cytoplasm_CENPA_mean_edge
# cytoplasm_centroid_c
# cytoplasm_eccentricity
# cytoplasm_major_axis
# cytoplasm_minor_axis
# cytoplasm_orientation
# cytoplasm_compactness
# cytoplasm_max_radius
# cytoplasm_median_radius
# cytoplasm_mean_radius
# cytoplasm_min_feret_diameter
# cytoplasm_max_feret_diameter
# cytoplasm_min_feret_r0
# cytoplasm_min_feret_c0
# cytoplasm_min_feret_r1
# cytoplasm_min_feret_c1
# cytoplasm_max_feret_r0
# cytoplasm_max_feret_c0
# cytoplasm_max_feret_r1
# cytoplasm_max_feret_c1
# cytoplasm_hu_moments_0
# cytoplasm_hu_moments_1
# cytoplasm_hu_moments_2
# cytoplasm_hu_moments_3
# cytoplasm_hu_moments_4
# cytoplasm_hu_moments_5
# cytoplasm_hu_moments_6
# cytoplasm_zernike_0_0
# cytoplasm_zernike_1_1
# cytoplasm_zernike_2_0
# cytoplasm_zernike_2_2
# cytoplasm_zernike_3_1
# cytoplasm_zernike_3_3
# cytoplasm_zernike_4_0
# cytoplasm_zernike_4_2
# cytoplasm_zernike_4_4
# cytoplasm_zernike_5_1
# cytoplasm_zernike_5_3
# cytoplasm_zernike_5_5
# cytoplasm_zernike_6_0
# cytoplasm_zernike_6_2
# cytoplasm_zernike_6_4
# cytoplasm_zernike_6_6
# cytoplasm_zernike_7_1
# cytoplasm_zernike_7_3
# cytoplasm_zernike_7_5
# cytoplasm_zernike_7_7
# cytoplasm_zernike_8_0
# cytoplasm_zernike_8_2
# cytoplasm_zernike_8_4
# cytoplasm_zernike_8_6
# cytoplasm_zernike_8_8
# cytoplasm_zernike_9_1
# cytoplasm_zernike_9_3
# cytoplasm_zernike_9_5
# cytoplasm_zernike_9_7
# cytoplasm_zernike_9_9
# cytoplasm_number_neighbors_1
# cytoplasm_percent_touching_1
# cytoplasm_first_neighbor_distance
# cytoplasm_second_neighbor_distance
# cytoplasm_angle_between_neighbors

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Cell Data Metadata
#
# - `METADATA_COLS_FP`: Path to TSV to store metadata cols.
# - `METADATA_COLS`: Columns in cell data with metadata (use output above).

# %%
METADATA_COLS_FP = "config/cell_data_metadata_cols.tsv"
METADATA_COLS = [
    "plate",
    "well",
    "tile",
    "cell_0",
    "i_0",
    "j_0",
    "site",
    "cell_1",
    "i_1",
    "j_1",
    "distance",
    "fov_distance_0",
    "fov_distance_1",
    "sgRNA_0",
    "gene_symbol_0",
    "mapped_single_gene",
    "channels_min",
    "nucleus_i",
    "nucleus_j",
    "nucleus_bounds_0",
    "nucleus_bounds_1",
    "nucleus_bounds_2",
    "nucleus_bounds_3",
    "cell_i",
    "cell_j",
    "cell_bounds_0",
    "cell_bounds_1",
    "cell_bounds_2",
    "cell_bounds_3",
    "cytoplasm_i",
    "cytoplasm_j",
    "cytoplasm_bounds_0",
    "cytoplasm_bounds_1",
    "cytoplasm_bounds_2",
    "cytoplasm_bounds_3",
]

# %%
pd.Series(METADATA_COLS).to_csv(METADATA_COLS_FP, index=False, header=False, sep="\t")

metadata, features = split_cell_data(cell_data, METADATA_COLS)
print(metadata.shape, features.shape)
# Out:
# (50000, 35) (50000, 1649)

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Split cells into classes
#
# - `CLASSIFIER_PATH`: Path to pickled Python object that can take a cell data dataframe and output cell classes
#
# ### Evaluate splitting
#
# - `COLLAPSE_COLS`: Cell data columns to collapse on when creating a summary of cell counts. This will show the number of cells in each cell class for these particular columns. Ex: `["sgRNA_0", "gene_symbol_0"]`.
# - `MONTAGE_CHANNEL`: Channel to use for montage generation. Usually `DAPI`.
#
# **Notes**:
# - We generate cell classes for each of the classes listed in the classifier and an "all" class. So for a classifier that splits by mitotic or interphase the final classes will be `["mitotic", "interphase", "all"]`.
# - You must import necessary packages for the classifier in this notebook and add them to `scripts/aggregate/split_datasets.py` as well. Ex `import numpy as np` if the classifier requires `numpy`.

# %%
CLASSIFIER_PATH = "config/binary_xgb_none_model.dill"
MONTAGE_CHANNEL = "DAPI"
COLLAPSE_COLS = ["sgRNA_0", "gene_symbol_0"]

import numpy as np

# %%
classifier = CellClassifier.load(CLASSIFIER_PATH)
classified_metadata, classified_features = classifier.classify_cells(metadata, features)

# Create config var for cell classes
CELL_CLASSES = list(classified_metadata["class"].unique())

# Show cell class counts and distribution
print("Cell class counts:")
print(classified_metadata["class"].value_counts())

print("\nCell class confidences:")
classified_metadata["confidence"].hist()
plt.show()
# Out:
# /home/rkern/miniconda3/envs/brieflow_denali_analysis_new/lib/python3.11/site-packages/sklearn/base.py:440: InconsistentVersionWarning: Trying to unpickle estimator Pipeline from version 1.6.1 when using version 1.7.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/rkern/miniconda3/envs/brieflow_denali_analysis_new/lib/python3.11/site-packages/sklearn/base.py:440: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.6.1 when using version 1.7.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Removing 1077 rows with NaN values in features
# Cell class counts:
# class
# Interphase    48135
# Mitotic         788
# Name: count, dtype: int64
#
# Cell class confidences:

# %%
cell_classes = list(classified_metadata["class"].unique()) + ["all"]

classified_metadata_copy = classified_metadata.copy(deep=True)
classified_metadata_copy = add_filenames(classified_metadata_copy, ROOT_FP)

# Create a dictionary of DataFrames for each cell class
cell_class_dfs = {
    cell_class: classified_metadata_copy[
        classified_metadata_copy["class"] == cell_class
    ]
    for cell_class in CELL_CLASSES
}

# Define sorting directions and titles
title_templates = {
    True: "Lowest Confidence {cell_class} Cells - {channel}",
    False: "Highest Confidence {cell_class} Cells - {channel}",
}

# Generate montages dynamically
montages, titles = [], []
for cell_class, cell_df in cell_class_dfs.items():
    for ascending in [True, False]:
        montage = create_cell_montage(
            cell_data=cell_df,
            channels=config["phenotype"]["channel_names"],
            selection_params={
                "method": "sorted",
                "sort_by": "confidence",
                "ascending": ascending,
            },
        )[MONTAGE_CHANNEL]
        montages.append(montage)
        titles.append(
            title_templates[ascending].format(
                cell_class=cell_class, channel=MONTAGE_CHANNEL
            )
        )

# Determine figure size dynamically
num_rows = len(CELL_CLASSES)
fig, axes = plt.subplots(num_rows, 2, figsize=(10, 3 * num_rows))

# Display montages
for ax, title, montage in zip(axes.flat, titles, montages):
    ax.imshow(montage, cmap="gray")
    ax.set_title(title, fontsize=14)
    ax.axis("off")

print("Montages of cell classes:")
plt.tight_layout()
plt.show()

print("Split cell data summary:")
summary_df = summarize_cell_data(classified_metadata, CELL_CLASSES, COLLAPSE_COLS)
display(summary_df)
# Out:
# Montages of cell classes:
# Split cell data summary:
#                       Stage  Count  Percent
# 0                  Raw Data  48923   100.00
# 1          Interphase cells  48135    98.39
# 2        Interphase sgRNA_0   9215    18.84
# 3  Interphase gene_symbol_0   4662     9.53
# 4             Mitotic cells    788     1.61
# 5           Mitotic sgRNA_0    173     0.35
# 6     Mitotic gene_symbol_0    172     0.35

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Aggregate by channel combos
#
# - `CHANNEL_COMBOS`: Combinations of channels to aggregate by. This is a list of lists with channel names, ex `[["DAPI", "CENPA"], ["DAPI", "WGA"]]`.
# - `AGGREGATE_COMBO_FP`: Location of aggregate combinations dataframe.
# - `TEST_CELL_CLASS`: Cell class to configure aggregate params with. Can be any of the cell classes or `all`.
# - `TEST_CHANNEL_COMBO`: Channel combo to configure aggregate params with; must be one of the channel combos. Ex `["DAPI", "CENPA"]`.

# %%
CHANNEL_COMBOS = [
    ["DAPI", "COXIV", "CENPA", "WGA"],
    ["DAPI", "CENPA"],
    ["DAPI", "WGA"],
]
AGGREGATE_COMBO_FP = "config/aggregate_combo.tsv"

TEST_CELL_CLASS = "all"
TEST_CHANNEL_COMBO = ["DAPI", "COXIV", "CENPA", "WGA"]

# %%
# determine cell classes and channel combos
channel_combos = ["_".join(combo) for combo in CHANNEL_COMBOS]

# Load merge wildcard combos
MERGE_COMBO_FP = Path(config["merge"]["merge_combo_fp"])
merge_wildcard_combos = pd.read_csv(MERGE_COMBO_FP, sep="\t")

# Generate aggregate wildcard combos
aggregate_wildcard_combos = pd.DataFrame(
    product(
        merge_wildcard_combos.itertuples(index=False, name=None),
        cell_classes,
        channel_combos,
    ),
    columns=["plate_well", "cell_class", "channel_combo"],
)
aggregate_wildcard_combos[["plate", "well"]] = pd.DataFrame(
    aggregate_wildcard_combos["plate_well"].tolist(),
    index=aggregate_wildcard_combos.index,
)
aggregate_wildcard_combos = aggregate_wildcard_combos.drop(columns="plate_well")

# Save aggregate wildcard combos
aggregate_wildcard_combos.to_csv(AGGREGATE_COMBO_FP, sep="\t", index=False)

print("Aggregate wildcard combos:")
aggregate_wildcard_combos
# Out:
# Aggregate wildcard combos:
#      cell_class         channel_combo  plate well
# 0    Interphase  DAPI_COXIV_CENPA_WGA      1   A3
# 1    Interphase            DAPI_CENPA      1   A3
# 2    Interphase              DAPI_WGA      1   A3
# 3       Mitotic  DAPI_COXIV_CENPA_WGA      1   A3
# 4       Mitotic            DAPI_CENPA      1   A3
# ..          ...                   ...    ...  ...
# 157     Mitotic            DAPI_CENPA      3   A1
# 158     Mitotic              DAPI_WGA      3   A1
# 159         all  DAPI_COXIV_CENPA_WGA      3   A1
# 160         all            DAPI_CENPA      3   A1
# 161         all              DAPI_WGA      3   A1
#
# [162 rows x 4 columns]

# %%
# subset cell class
if TEST_CELL_CLASS != "all":
    cell_class_mask = classified_metadata["class"] == TEST_CELL_CLASS
    class_metadata = classified_metadata[cell_class_mask]
    class_features = classified_features[cell_class_mask]
else:
    class_metadata = classified_metadata
    class_features = classified_features

# subset features
all_channels = config["phenotype"]["channel_names"]
class_features = channel_combo_subset(class_features, TEST_CHANNEL_COMBO, all_channels)

# copy metadata and features for later eval
dataset_metadata = class_metadata.copy()
dataset_features = class_features.copy()

# preview metadata and features
display(class_metadata)
display(class_features)
# Out:
#        plate well  tile  cell_0          i_0          j_0  site  cell_1  \
# 0          1   A1  1045     438  1478.403947  1481.714474   243     265
# 1          1   A1   401     494  1477.766431  1478.877654   101     302
# 2          1   A1  1502     507  1480.628283  1477.384343   354     282
# 3          1   A1   595     482  1480.676399  1482.874696   154     228
# 4          1   A1  1479     613  1477.695030  1481.850904   365     360
# ...      ...  ...   ...     ...          ...          ...   ...     ...
# 49995      1   A2  1266     489  1420.418016  1664.271255   305     198
# 49996      1   A2  1182     677  1520.975945  1290.717526   302     365
# 49997      1   A2  1234     424  1511.256988  1671.142081   290    1781
# 49998      1   A2   765     431  1571.396514  1650.772876   192     248
# 49999      1   A2  1306     537  1591.093674  1321.326642   318    1966
#
#               i_1         j_1  ...  cell_bounds_2  cell_bounds_3  cytoplasm_i  \
# 0      100.072917  670.520833  ...           1500           1524  1477.396009
# 1      100.089552  669.910448  ...           1506           1501  1478.454990
# 2      100.674419   99.806202  ...           1514           1513  1483.432210
# 3      100.764706  670.764706  ...           1500           1500  1477.067024
# 4       99.273810  671.380952  ...           1511           1507  1474.529360
# ...           ...         ...  ...            ...            ...          ...
# 49995   84.565217  717.318841  ...           1441           1688  1423.156495
# 49996  109.670588   52.788235  ...           1541           1322  1517.579132
# 49997  678.524390  719.500000  ...           1534           1711  1510.977002
# 49998  122.725000  713.541667  ...           1601           1700  1573.989630
# 49999  700.198020   61.693069  ...           1631           1350  1592.218274
#
#        cytoplasm_j cytoplasm_bounds_0 cytoplasm_bounds_1  cytoplasm_bounds_2  \
# 0      1473.735994               1457               1438                1500
# 1      1475.301370               1452               1454                1506
# 2      1471.929334               1452               1440                1514
# 3      1472.863271               1459               1460                1500
# 4      1477.583699               1447               1449                1511
# ...            ...                ...                ...                 ...
# 49995  1660.920188               1401               1637                1441
# 49996  1277.559203               1499               1249                1541
# 49997  1677.449643               1490               1634                1534
# 49998  1653.747160               1542               1611                1601
# 49999  1322.967640               1558               1292                1631
#
#        cytoplasm_bounds_3       class  confidence
# 0                    1524  Interphase    0.999661
# 1                    1501  Interphase    0.998782
# 2                    1513  Interphase    0.997050
# 3                    1500  Interphase    0.997721
# 4                    1507  Interphase    0.999407
# ...                   ...         ...         ...
# 49995                1688  Interphase    0.992437
# 49996                1322  Interphase    0.998528
# 49997                1711  Interphase    0.999176
# 49998                1700  Interphase    0.996402
# 49999                1350  Interphase    0.998867
#
# [48923 rows x 37 columns]
#        nucleus_DAPI_int  nucleus_COXIV_int  nucleus_CENPA_int  \
# 0               4094709             563558             598918
# 1               3451583             473786             481848
# 2               8374966             705205             772320
# 3               3963469             374286             412576
# 4               3901274             370204             434712
# ...                 ...                ...                ...
# 49995           3764680             401018             450117
# 49996           4126058             398573             561469
# 49997           4236055             419774             520008
# 49998           6313619             489747             623635
# 49999           4711927             550489             612539
#
#        nucleus_WGA_int  nucleus_DAPI_mean  nucleus_COXIV_mean  \
# 0              5639609        2693.887500          370.761842
# 1              3737416        3489.972700          479.055612
# 2              6252227        4229.780808          356.164141
# 3              2641324        4821.738443          455.335766
# 4              2603808        2937.706325          278.768072
# ...                ...                ...                 ...
# 49995          2503446        3810.404858          405.888664
# 49996          3061849        2835.778694          273.933333
# 49997          3438762        3288.862578          325.911491
# 49998          4367871        3438.790305          266.746732
# 49999          3966111        2866.135645          334.847324
#
#        nucleus_CENPA_mean  nucleus_WGA_mean  nucleus_DAPI_std  \
# 0              394.025000       3710.269079        442.450180
# 1              487.207280       3778.984833        677.083422
# 2              390.060606       3157.690404        705.971034
# 3              501.917275       3213.289538       1145.039846
# 4              327.343373       1960.698795        512.928871
# ...                   ...               ...               ...
# 49995          455.584008       2533.852227        748.596260
# 49996          385.889347       2104.363574        509.084757
# 49997          403.732919       2669.846273        856.726088
# 49998          339.670479       2379.014706        660.813294
# 49999          372.590633       2412.476277        493.074802
#
#        nucleus_COXIV_std  ...  cytoplasm_zernike_9_1  cytoplasm_zernike_9_3  \
# 0              67.105238  ...               0.074622               0.120079
# 1              75.658417  ...               0.075236               0.016084
# 2              63.106370  ...               0.130661               0.127964
# 3              73.915248  ...               0.200692               0.058719
# 4              47.370246  ...               0.195139               0.024621
# ...                  ...  ...                    ...                    ...
# 49995          69.411754  ...               0.204233               0.195177
# 49996          47.327698  ...               0.131995               0.107407
# 49997          61.130155  ...               0.040305               0.051572
# 49998          44.036745  ...               0.048048               0.161640
# 49999          62.111139  ...               0.047520               0.177541
#
#        cytoplasm_zernike_9_5  cytoplasm_zernike_9_7  cytoplasm_zernike_9_9  \
# 0                   0.106608               0.043195               0.059320
# 1                   0.022822               0.033249               0.008095
# 2                   0.029040               0.006776               0.012450
# 3                   0.026384               0.011026               0.016833
# 4                   0.102549               0.077403               0.025830
# ...                      ...                    ...                    ...
# 49995               0.077798               0.028220               0.011759
# 49996               0.174412               0.075434               0.020633
# 49997               0.076769               0.061677               0.025688
# 49998               0.054195               0.043290               0.011734
# 49999               0.075033               0.012954               0.038279
#
#        cytoplasm_number_neighbors_1  cytoplasm_percent_touching_1  \
# 0                                 0                      0.000000
# 1                                 1                      0.037791
# 2                                 0                      0.000000
# 3                                 2                      0.068627
# 4                                 0                      0.000000
# ...                             ...                           ...
# 49995                             0                      0.000000
# 49996                             0                      0.000000
# 49997                             1                      0.103365
# 49998                             0                      0.000000
# 49999                             0                      0.000000
#
#        cytoplasm_first_neighbor_distance  cytoplasm_second_neighbor_distance  \
# 0                              48.615252                           55.257173
# 1                              40.275758                           56.068075
# 2                              52.963143                           70.225474
# 3                              38.735022                           47.030219
# 4                              62.404446                           63.974515
# ...                                  ...                                 ...
# 49995                          68.133456                           84.498758
# 49996                          76.360067                           79.143785
# 49997                          51.946855                           56.660722
# 49998                          89.306692                          106.507049
# 49999                          78.079100                           85.789058
#
#        cytoplasm_angle_between_neighbors
# 0                             159.483845
# 1                             115.752777
# 2                             167.657553
# 3                             157.402576
# 4                             134.672172
# ...                                  ...
# 49995                         169.942383
# 49996                         123.722519
# 49997                         158.502934
# 49998                          30.410540
# 49999                          45.775893
#
# [48923 rows x 1649 columns]

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Perturbation filtering
#
# - `FILTER_QUERIES`: Queries to use for custom filtering; ex: `["mapped_single_gene == True", "cell_quality_score > 0.8"]`. Can be left as `None` for no filtering.
# - `PERTURBATION_NAME_COL`: Name of column used to identify perturbations. This is the column that aggregation takes place on. Ex "gene_symbol_0".

# %%
FILTER_QUERIES = ["mapped_single_gene == True"]
PERTURBATION_NAME_COL = "gene_symbol_0"

# %%
qf_metadata, qf_features = query_filter(class_metadata, class_features, FILTER_QUERIES)

pf_metadata, pf_features = perturbation_filter(
    qf_metadata, qf_features, PERTURBATION_NAME_COL
)
print(f"Unique populations: {metadata[PERTURBATION_NAME_COL].nunique()}")

summary_df, fig = nas_summary(pf_features)
print(summary_df[summary_df["percent_na"] > 0.1])
plt.show()
# Out:
# Query 'mapped_single_gene == True' filtered out 31281 cells
# Found 17642 cells with assigned perturbations
# Unique populations: 4689
#                          column  percent_na
# 39   cytoplasm_DAPI_mean_frac_0    0.711937
# 40  cytoplasm_COXIV_mean_frac_0    0.711937
# 41  cytoplasm_CENPA_mean_frac_0    0.711937
# 42    cytoplasm_WGA_mean_frac_0    0.711937
# 43   cytoplasm_DAPI_mean_frac_1    0.661150
# 44  cytoplasm_COXIV_mean_frac_1    0.661150
# 45  cytoplasm_CENPA_mean_frac_1    0.661150
# 46    cytoplasm_WGA_mean_frac_1    0.661150
# 47   cytoplasm_DAPI_radial_cv_0    0.711937
# 48  cytoplasm_COXIV_radial_cv_0    0.711937
# 49  cytoplasm_CENPA_radial_cv_0    0.711937
# 50    cytoplasm_WGA_radial_cv_0    0.711937
# 51   cytoplasm_DAPI_radial_cv_1    0.661150
# 52  cytoplasm_COXIV_radial_cv_1    0.661150
# 53  cytoplasm_CENPA_radial_cv_1    0.661150
# 54    cytoplasm_WGA_radial_cv_1    0.661150

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Missing value filtering
#
# - `DROP_COLS_THRESHOLD`: Threshold of NA values above which an entire column is dropped. Usually `0.1`
# - `DROP_ROWS_THRESHOLD`: Threshold of NA values above which an entire row is dropped. Usually `0.01`
# - `IMPUTE`: Whether or not to impute remaining missing values. Usually `True`
#
# **Note**: All NAs must be dropped or imputed to perform feature alignment.

# %%
DROP_COLS_THRESHOLD = 0.1
DROP_ROWS_THRESHOLD = 0.01
IMPUTE = True

# %%
# Filter by missing values
mvf_metadata, mvf_features = missing_values_filter(
    pf_metadata,
    pf_features,
    drop_cols_threshold=DROP_COLS_THRESHOLD,
    drop_rows_threshold=DROP_ROWS_THRESHOLD,
    impute=True,
)

mvf_metadata.shape, mvf_features.shape
# Out:
# Dropping 16 columns with ≥10.0% missing values
# Dropped 24 rows with ≥1.0% missing values
# Imputing 39 columns with remaining missing values using batched KNN
# Imputing for batch 1 with 359 NA rows
# ((17618, 37), (17618, 1633))

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Intensity filtering
#
# - `CONTAMINATION`: Expected proportion of outliers in dataset. Usually `0.01`

# %%
CONTAMINATION = 0.01

# %%
# Filter by intensity outliers
if_metadata, if_features = intensity_filter(
    mvf_metadata,
    mvf_features,
    config["phenotype"]["channel_names"],
    CONTAMINATION,
)

if_metadata.shape, if_features.shape
# Out:
# ((17441, 37), (17441, 1633))

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Prepare alignment data
#
# - `BATCH_COLS`: Which columns of metadata have batch-specific information. Usually `["plate", "well"]`.
# - `CONTROL_KEY`: Name of perturbation in `PERTURBATION_NAME_COL` that indicates a control cell.
# - `PERTURBATION_ID_COL`: Name of column that identifies unique perturbations. Only needed if you want your controls to have different perturbation names, ex `sgRNA_0`. Otherwise, can leave this as `None`.

# %%
BATCH_COLS = ["plate", "well"]
CONTROL_KEY = "nontargeting"
PERTURBATION_ID_COL = "sgRNA_0"

# %%
pad_metadata, pad_features = prepare_alignment_data(
    if_metadata,
    if_features,
    BATCH_COLS,
    PERTURBATION_NAME_COL,
    CONTROL_KEY,
    PERTURBATION_ID_COL,
)

n_components, fig = pca_variance_plot(pad_features, variance_threshold=0.99)
plt.show()

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Align and aggregate
#
# - `VARIANCE_OR_NCOMP`: Variance or number of components to keep after PCA.
# - `NUM_ALIGN_BATCHES`: Number of batches to use when aligning, usually `1`. Increase this if you are running out of memory while aligning. We were able to barely fit 8 plates with 6 wells each in 1 TB of memory with `NUM_ALIGN_BATCHES=1`.
# - `AGG_METHOD`: Method used to aggregate features. Can be `mean` or `median`. Usually `median`.
#
# While we use a simplified aggregate method in the notebook, the way this works during a normal run is:
# 1) Take a subset of 1,000,000 cells, or the entire dataset, whichever is smaller and compute a PCA transform with `VARIANCE_OR_NCOMP`.
# 2) Subset the entire dataset `NUM_BATCHES` number of times and align cells in this batch.
# 3) Aggregate across all aligned cell data.

# %%
VARIANCE_OR_NCOMP = 0.99
NUM_ALIGN_BATCHES = 1
AGG_METHOD = "median"

# %%
pca_embeddings = embed_by_pca(
    pad_features,
    pad_metadata,
    variance_or_ncomp=VARIANCE_OR_NCOMP,
    batch_col="batch_values",
)

tvn_normalized = tvn_on_controls(
    pca_embeddings, pad_metadata, PERTURBATION_NAME_COL, CONTROL_KEY, "batch_values"
)

aggregated_embeddings, aggregated_metadata = aggregate(
    tvn_normalized, pad_metadata, PERTURBATION_NAME_COL, AGG_METHOD
)

feature_columns = [f"PC_{i}" for i in range(tvn_normalized.shape[1])]

tvn_normalized_df = pd.DataFrame(
    tvn_normalized, index=pad_metadata.index, columns=feature_columns
)
aligned_cell_data = pd.concat([pad_metadata, tvn_normalized_df], axis=1)

aggregated_embeddings_df = pd.DataFrame(
    aggregated_embeddings, index=aggregated_metadata.index, columns=feature_columns
)
aggregated_cell_data = (
    pd.concat([aggregated_metadata, aggregated_embeddings_df], axis=1)
    .sort_values("cell_count", ascending=False)
    .reset_index(drop=True)
)
# Out:
# /lab/ops_analysis/cheeseman/denali-analysis-new/brieflow/workflow/lib/aggregate/align.py:244: FutureWarning: Logical ops (and, or, xor) between Pandas objects and dtype-less sequences (e.g. list, tuple) are deprecated and will raise in a future version. Wrap the object in a Series, Index, or np.array before operating instead.
#   batch_ind & (metadata[pert_col].str.startswith(control_key)).to_list()
# /lab/ops_analysis/cheeseman/denali-analysis-new/brieflow/workflow/lib/aggregate/align.py:244: FutureWarning: Logical ops (and, or, xor) between Pandas objects and dtype-less sequences (e.g. list, tuple) are deprecated and will raise in a future version. Wrap the object in a Series, Index, or np.array before operating instead.
#   batch_ind & (metadata[pert_col].str.startswith(control_key)).to_list()
# /lab/ops_analysis/cheeseman/denali-analysis-new/brieflow/workflow/lib/aggregate/align.py:174: FutureWarning: Logical ops (and, or, xor) between Pandas objects and dtype-less sequences (e.g. list, tuple) are deprecated and will raise in a future version. Wrap the object in a Series, Index, or np.array before operating instead.
#   batch_ind & (metadata[pert_col].str.startswith(control_key)).to_list()
# /lab/ops_analysis/cheeseman/denali-analysis-new/brieflow/workflow/lib/aggregate/align.py:179: ComplexWarning: Casting complex values to real discards the imaginary part
#   embeddings[batch_ind] = np.matmul(
# /lab/ops_analysis/cheeseman/denali-analysis-new/brieflow/workflow/lib/aggregate/align.py:174: FutureWarning: Logical ops (and, or, xor) between Pandas objects and dtype-less sequences (e.g. list, tuple) are deprecated and will raise in a future version. Wrap the object in a Series, Index, or np.array before operating instead.
#   batch_ind & (metadata[pert_col].str.startswith(control_key)).to_list()
# /lab/ops_analysis/cheeseman/denali-analysis-new/brieflow/workflow/lib/aggregate/align.py:179: ComplexWarning: Casting complex values to real discards the imaginary part
#   embeddings[batch_ind] = np.matmul(

# %%
original_feature_cols = [
    col
    for col in dataset_features.columns
    if ("cell_" in col and col.endswith("_mean"))
]
pc_cols = [col for col in aggregated_cell_data.columns if col.startswith("PC_")]
aligned_feature_cols = random.sample(
    pc_cols, k=min(len(original_feature_cols), len(pc_cols))
)

original_cell_data = pd.concat([dataset_metadata, dataset_features], axis=1)
original_cell_data

feature_distributions_fig = plot_feature_distributions(
    original_feature_cols,
    original_cell_data,
    aligned_feature_cols,
    aligned_cell_data,
)
plt.show()
# Out:
# /lab/ops_analysis/cheeseman/denali-analysis-new/brieflow/workflow/lib/aggregate/eval_aggregate.py:130: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_orig = df_orig.groupby(["Feature", "plate_well"], group_keys=False).apply(
# /lab/ops_analysis/cheeseman/denali-analysis-new/brieflow/workflow/lib/aggregate/eval_aggregate.py:136: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_aligned = df_aligned.groupby(["Feature", "plate_well"], group_keys=False).apply(

# %% [markdown]
# ## Add aggregate parameters to config file

# %%
# Add aggregate section
config["aggregate"] = {
    "metadata_cols_fp": METADATA_COLS_FP,
    "collapse_cols": COLLAPSE_COLS,
    "classifier_path": CLASSIFIER_PATH,
    "aggregate_combo_fp": AGGREGATE_COMBO_FP,
    "filter_queries": FILTER_QUERIES,
    "perturbation_name_col": PERTURBATION_NAME_COL,
    "drop_cols_threshold": DROP_COLS_THRESHOLD,
    "drop_rows_threshold": DROP_ROWS_THRESHOLD,
    "impute": IMPUTE,
    "contamination": CONTAMINATION,
    "batch_cols": BATCH_COLS,
    "control_key": CONTROL_KEY,
    "perturbation_id_col": PERTURBATION_ID_COL,
    "variance_or_ncomp": VARIANCE_OR_NCOMP,
    "num_align_batches": NUM_ALIGN_BATCHES,
    "agg_method": AGG_METHOD,
}

# Write the updated configuration
with open(CONFIG_FILE_PATH, "w") as config_file:
    # Write the introductory comments
    config_file.write(CONFIG_FILE_HEADER)

    # Dump the updated YAML structure, keeping markdown comments for sections
    yaml.dump(config, config_file, default_flow_style=False, sort_keys=False)
