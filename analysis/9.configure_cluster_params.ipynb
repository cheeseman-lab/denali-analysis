# %% [markdown]
# # Configure Cluster Module Params
#
# This notebook should be used as a test for ensuring correct cluster parameters before cluster processing.
# Cells marked with <font color='red'>SET PARAMETERS</font> contain crucial variables that need to be set according to your specific experimental setup and data organization.
# Please review and modify these variables as needed before proceeding with the analysis.

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Fixed parameters for cluster module
#
# - `CONFIG_FILE_PATH`: Path to a Brieflow config file used during processing. Absolute or relative to where workflows are run from.

# %%
CONFIG_FILE_PATH = "config/config.yml"

# %%
from pathlib import Path

import yaml
import pandas as pd
from matplotlib import pyplot as plt

from lib.cluster.cluster_eval import plot_cell_histogram
from lib.cluster.generate_dataset import (
    clean_and_validate,
    split_channels,
    remove_low_number_genes,
    remove_missing_features,
)
from lib.cluster.phate_leiden_clustering import (
    select_features,
    normalize_to_controls,
    perform_pca_analysis,
    phate_leiden_pipeline,
    dimensionality_reduction,
    merge_phate_uniprot,
)
from lib.cluster.benchmark_clusters import (
    create_cluster_gene_table,
    analyze_differential_features,
    process_interactions,
)
from lib.cluster.scrape_benchmarks import (
    get_uniprot_data,
    get_string_data,
    get_corum_data,
)
from lib.shared.configuration_utils import CONFIG_FILE_HEADER

# %%
# load config file and determine root path
with open(CONFIG_FILE_PATH, "r") as config_file:
    config = yaml.safe_load(config_file)
    ROOT_FP = Path(config["all"]["root_fp"])

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Cluster processing
#
# - `CHANNEL_COMBOS`: Combinations of channels to use during cluster process.
# - `DATASET_TYPES`: Dataset types to use during cluster process; created during the aggregate process.
# - `MIN_CELL_CUTOFFS`: Minimum cells for each gene to be used in clusetering analysis. More cells per gene increases confidence, but some dataset types (ex mitotic) may have an inherently low number of cells for a particular perturbation.

# %%
# parameters for all cluster processing
CHANNEL_COMBOS = [
    ["DAPI", "COXIV", "CENPA", "WGA"],
    ["DAPI", "CENPA"],
]
DATASET_TYPES = ["mitotic", "interphase", "all"]
MIN_CELL_CUTOFFS = {"mitotic": 0, "interphase": 3, "all": 3}

# %%
for dataset_type, min_cell_cutoff in MIN_CELL_CUTOFFS.items():
    # load and clean relevant dataset
    gene_data_fp = ROOT_FP / "aggregate" / "tsvs" / f"{dataset_type}_gene_data.tsv"
    gene_data = pd.read_csv(gene_data_fp, sep="\t")
    cleaned_data = clean_and_validate(gene_data)

    # show cell count distribution
    print(f"Cell count distribution for: {dataset_type}")
    plot_cell_histogram(cleaned_data, min_cell_cutoff)
    plt.show()

    break #TODO: REMOVE
# Out:
# Cell count distribution for: mitotic
# Number of genes below cutoff: 0
# []

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Cluster testing
#
# - `TEST_CHANNEL_COMBO`: Channel combination to use for testing cluster process. Should be smallest or most relevant channel combination.
# - `TEST_DATASET_TYPE`: Dataset type to use for testing cluster process. Should be smallest or most relevant dataset type.

# %%
# parameters for testing cluster processing
TEST_CHANNEL_COMBO = ["DAPI", "COXIV", "CENPA", "WGA"]
TEST_DATASET_TYPE = "all"

# %%
# load gene data based on dataset we are processing
gene_data_fp = ROOT_FP / "aggregate" / "tsvs" / f"{TEST_DATASET_TYPE}_gene_data.tsv"
gene_data = pd.read_csv(gene_data_fp, sep="\t")

# clean and validate gene data
validated_data = clean_and_validate(gene_data)

# filter dataset for channels of interest
channel_filtered_data = split_channels(
    validated_data,
    TEST_CHANNEL_COMBO,
    config["phenotype"]["channel_names"],
)

# clean low number genes and missing features
cleaned_data = remove_low_number_genes(
    channel_filtered_data, MIN_CELL_CUTOFFS[TEST_DATASET_TYPE]
)
cleaned_data = remove_missing_features(cleaned_data)

cleaned_data
# Out:
# Gene Filtering Summary:
# Original genes: 5299
# Genes with < 3 cells: 0
# Remaining genes: 5299
#
# Feature Cleaning Summary:
# Original features: 1665
#
# Removed features:
#
# Features with infinite values (49):
# - nucleus_WGA_pftas_17
# - nucleus_WGA_pftas_25
# - nucleus_WGA_pftas_26
# - nucleus_COXIV_haralick_5_1
# - nucleus_COXIV_haralick_5_3
# - nucleus_COXIV_haralick_5_6
# - nucleus_euler_number
# - cell_WGA_pftas_17
# - cell_WGA_pftas_25
# - cell_WGA_pftas_26
# - cell_DAPI_pftas_44
# - cell_COXIV_haralick_5_1
# - cell_COXIV_haralick_5_3
# - cell_COXIV_haralick_5_6
# - cell_euler_number
# - cytoplasm_DAPI_frac_at_d_0
# - cytoplasm_COXIV_frac_at_d_0
# - cytoplasm_CENPA_frac_at_d_0
# - cytoplasm_WGA_frac_at_d_0
# - cytoplasm_DAPI_frac_at_d_1
# - cytoplasm_COXIV_frac_at_d_1
# - cytoplasm_CENPA_frac_at_d_1
# - cytoplasm_WGA_frac_at_d_1
# - cytoplasm_DAPI_pftas_7
# - cytoplasm_DAPI_pftas_8
# - cytoplasm_WGA_pftas_8
# - cytoplasm_DAPI_pftas_16
# - cytoplasm_DAPI_pftas_17
# - cytoplasm_WGA_pftas_17
# - cytoplasm_DAPI_pftas_24
# - cytoplasm_WGA_pftas_24
# - cytoplasm_DAPI_pftas_25
# - cytoplasm_WGA_pftas_25
# - cytoplasm_DAPI_pftas_26
# - cytoplasm_COXIV_pftas_26
# - cytoplasm_CENPA_pftas_26
# - cytoplasm_WGA_pftas_26
# - cytoplasm_DAPI_pftas_44
# - cytoplasm_DAPI_pftas_45
# - cytoplasm_DAPI_pftas_46
# - cytoplasm_euler_number
# - cell_CENPA_foci_count
# - cell_CENPA_foci_area
# - nucleus_number_neighbors_1
# - nucleus_percent_touching_1
# - cell_number_neighbors_1
# - cell_percent_touching_1
# - cytoplasm_number_neighbors_1
# - cytoplasm_percent_touching_1
#
# Features with null/NA values (37):
# - cytoplasm_DAPI_mean_frac_0
# - cytoplasm_COXIV_mean_frac_0
# - cytoplasm_CENPA_mean_frac_0
# - cytoplasm_WGA_mean_frac_0
# - cytoplasm_DAPI_mean_frac_1
# - cytoplasm_COXIV_mean_frac_1
# - cytoplasm_CENPA_mean_frac_1
# - cytoplasm_WGA_mean_frac_1
# - cytoplasm_DAPI_mean_frac_2
# - cytoplasm_COXIV_mean_frac_2
# - cytoplasm_CENPA_mean_frac_2
# - cytoplasm_WGA_mean_frac_2
# - cytoplasm_DAPI_radial_cv_0
# - cytoplasm_COXIV_radial_cv_0
# - cytoplasm_CENPA_radial_cv_0
# - cytoplasm_WGA_radial_cv_0
# - cytoplasm_DAPI_radial_cv_1
# - cytoplasm_COXIV_radial_cv_1
# - cytoplasm_CENPA_radial_cv_1
# - cytoplasm_WGA_radial_cv_1
# - cytoplasm_DAPI_radial_cv_2
# - cytoplasm_COXIV_radial_cv_2
# - cytoplasm_CENPA_radial_cv_2
# - cytoplasm_WGA_radial_cv_2
# - cytoplasm_COXIV_haralick_5_0
# - cytoplasm_COXIV_haralick_5_1
# - cytoplasm_COXIV_haralick_5_2
# - cytoplasm_COXIV_haralick_5_3
# - cytoplasm_COXIV_haralick_5_4
# - cytoplasm_COXIV_haralick_5_5
# - cytoplasm_COXIV_haralick_5_6
# - cytoplasm_COXIV_haralick_5_7
# - cytoplasm_COXIV_haralick_5_8
# - cytoplasm_COXIV_haralick_5_9
# - cytoplasm_COXIV_haralick_5_10
# - cytoplasm_COXIV_haralick_5_11
# - cytoplasm_COXIV_haralick_5_12
#
# Remaining features: 1579
#         gene_symbol_0  cell_number  nucleus_DAPI_mean  nucleus_COXIV_mean  \
# 0                AAAS         3691          -0.043224           -0.039970
# 1               AAGAB         4178          -0.091268           -0.097120
# 2                AAK1         2567           0.061767            0.061792
# 3                AAMP         2037           0.423494           -0.233015
# 4               AARS1         2452          -0.060148           -0.201978
# ...               ...          ...                ...                 ...
# 5294  nontargeting_95         1486          -0.009526            0.007624
# 5295  nontargeting_96          738          -0.068228           -0.078192
# 5296  nontargeting_97          590          -0.160469           -0.088912
# 5297  nontargeting_98          889          -0.095751           -0.058520
# 5298  nontargeting_99         1683           0.000919            0.041743
#
#       nucleus_CENPA_mean  nucleus_WGA_mean  nucleus_DAPI_std  \
# 0              -0.053939          0.005555          0.016624
# 1              -0.124921         -0.082497         -0.091261
# 2               0.005954          0.045365         -0.045326
# 3               0.009982         -0.168016          0.410169
# 4              -0.085488         -0.167168         -0.039671
# ...                  ...               ...               ...
# 5294           -0.014476          0.007904         -0.014039
# 5295           -0.106603          0.002483         -0.051139
# 5296           -0.080456         -0.041052         -0.121200
# 5297           -0.040435         -0.003577         -0.052059
# 5298            0.093978          0.000594          0.022176
#
#       nucleus_COXIV_std  nucleus_CENPA_std  nucleus_WGA_std  ...  \
# 0             -0.053082          -0.104391        -0.082895  ...
# 1             -0.059733          -0.081791        -0.232732  ...
# 2              0.075346          -0.172371         0.115382  ...
# 3             -0.380411           0.091276        -0.272749  ...
# 4             -0.188223          -0.025304        -0.093873  ...
# ...                 ...                ...              ...  ...
# 5294          -0.013495          -0.030392        -0.000299  ...
# 5295          -0.095633          -0.044395        -0.071844  ...
# 5296          -0.079217          -0.033682        -0.038676  ...
# 5297          -0.007646          -0.009690        -0.043169  ...
# 5298           0.038086           0.081910         0.065426  ...
#
#       cytoplasm_bounds_3  nucleus_first_neighbor_distance  \
# 0               0.097360                         0.061069
# 1               0.009207                         0.008684
# 2               0.068003                        -0.043441
# 3              -0.077270                        -0.172830
# 4               0.136830                         0.061335
# ...                  ...                              ...
# 5294            0.074295                         0.026770
# 5295            0.015356                         0.116579
# 5296           -0.075477                         0.065862
# 5297            0.128361                        -0.006149
# 5298           -0.120546                        -0.085975
#
#       nucleus_second_neighbor_distance  nucleus_angle_between_neighbors  \
# 0                             0.136478                        -0.011510
# 1                             0.025149                        -0.022514
# 2                            -0.012601                        -0.135272
# 3                            -0.145169                        -0.065281
# 4                             0.104752                        -0.039316
# ...                                ...                              ...
# 5294                          0.020026                         0.016863
# 5295                          0.137272                        -0.036525
# 5296                          0.057305                        -0.053405
# 5297                         -0.024593                         0.027337
# 5298                         -0.068031                        -0.005585
#
#       cell_first_neighbor_distance  cell_second_neighbor_distance  \
# 0                         0.091766                       0.124078
# 1                         0.037120                       0.007819
# 2                        -0.040547                      -0.026865
# 3                        -0.147144                      -0.128533
# 4                         0.046209                       0.143285
# ...                            ...                            ...
# 5294                      0.040476                       0.005527
# 5295                      0.136140                       0.114546
# 5296                      0.080695                       0.081449
# 5297                      0.009884                      -0.012264
# 5298                     -0.065405                      -0.062405
#
#       cell_angle_between_neighbors  cytoplasm_first_neighbor_distance  \
# 0                         0.002455                           0.067050
# 1                        -0.033004                           0.018653
# 2                        -0.130039                          -0.002738
# 3                        -0.035737                          -0.126620
# 4                        -0.026073                           0.074235
# ...                            ...                                ...
# 5294                     -0.004402                           0.037376
# 5295                     -0.018593                           0.191812
# 5296                      0.011527                           0.057014
# 5297                      0.025457                          -0.020282
# 5298                     -0.010402                          -0.082772
#
#       cytoplasm_second_neighbor_distance  cytoplasm_angle_between_neighbors
# 0                               0.097289                          -0.029682
# 1                               0.018123                          -0.036049
# 2                               0.030603                          -0.073141
# 3                              -0.148200                          -0.029065
# 4                               0.161979                          -0.064552
# ...                                  ...                                ...
# 5294                            0.038317                           0.002750
# 5295                            0.176152                          -0.046862
# 5296                            0.050908                          -0.035474
# 5297                            0.033603                          -0.014498
# 5298                           -0.110535                           0.005846
#
# [5299 rows x 1579 columns]

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Feature selection
#
# - `CORRELATION_THRESHOLD`: Features with a correlation (to another feature) above this threshold are iteratively removed to get "unique" features.
# - `VARIANCE_THRESHOLD`: Features with variance below this threshold are removed.
# - `MIN_UNIQUE_VALUES`: Features with a number of unique values below this threshold are removed.

# %%
# parameters used for feature selection
CORRELATION_THRESHOLD = 0.99
VARIANCE_THRESHOLD = 0.001
MIN_UNIQUE_VALUES = 5

# %%
# select features
filtered_data, removed_features = select_features(
    cleaned_data,
    correlation_threshold=CORRELATION_THRESHOLD,
    variance_threshold=VARIANCE_THRESHOLD,
    min_unique_values=MIN_UNIQUE_VALUES,
)

filtered_data
# Out:
# Feature Selection Summary:
# Original features: 1577
# Features removed due to correlation: 121
# Features removed due to low variance: 25
# Features removed due to few unique values: 0
# Final features: 1431
#         gene_symbol_0  nucleus_COXIV_mean  nucleus_WGA_mean  \
# 0                AAAS           -0.039970          0.005555
# 1               AAGAB           -0.097120         -0.082497
# 2                AAK1            0.061792          0.045365
# 3                AAMP           -0.233015         -0.168016
# 4               AARS1           -0.201978         -0.167168
# ...               ...                 ...               ...
# 5294  nontargeting_95            0.007624          0.007904
# 5295  nontargeting_96           -0.078192          0.002483
# 5296  nontargeting_97           -0.088912         -0.041052
# 5297  nontargeting_98           -0.058520         -0.003577
# 5298  nontargeting_99            0.041743          0.000594
#
#       nucleus_COXIV_std  nucleus_CENPA_std  nucleus_WGA_std  nucleus_DAPI_max  \
# 0             -0.053082          -0.104391        -0.082895          0.003439
# 1             -0.059733          -0.081791        -0.232732         -0.066192
# 2              0.075346          -0.172371         0.115382         -0.018799
# 3             -0.380411           0.091276        -0.272749          0.393291
# 4             -0.188223          -0.025304        -0.093873         -0.078566
# ...                 ...                ...              ...               ...
# 5294          -0.013495          -0.030392        -0.000299         -0.049251
# 5295          -0.095633          -0.044395        -0.071844         -0.039963
# 5296          -0.079217          -0.033682        -0.038676         -0.162283
# 5297          -0.007646          -0.009690        -0.043169         -0.089284
# 5298           0.038086           0.081910         0.065426         -0.026832
#
#       nucleus_COXIV_max  nucleus_CENPA_max  nucleus_WGA_max  ...  \
# 0             -0.038217          -0.063451         0.002293  ...
# 1             -0.076443          -0.069782        -0.195881  ...
# 2              0.068535          -0.068797         0.096765  ...
# 3             -0.367295          -0.000777        -0.185041  ...
# 4             -0.151053           0.031690        -0.071918  ...
# ...                 ...                ...              ...  ...
# 5294           0.000000          -0.042690        -0.020115  ...
# 5295          -0.071608          -0.023510        -0.106771  ...
# 5296          -0.025786          -0.136272        -0.020298  ...
# 5297          -0.043799          -0.065274        -0.056389  ...
# 5298           0.033725           0.085380         0.067957  ...
#
#       cytoplasm_bounds_2  nucleus_first_neighbor_distance  \
# 0               0.033705                         0.061069
# 1              -0.017333                         0.008684
# 2              -0.041115                        -0.043441
# 3               0.029846                        -0.172830
# 4              -0.053886                         0.061335
# ...                  ...                              ...
# 5294           -0.087014                         0.026770
# 5295            0.016394                         0.116579
# 5296            0.008148                         0.065862
# 5297           -0.048568                        -0.006149
# 5298            0.068608                        -0.085975
#
#       nucleus_second_neighbor_distance  nucleus_angle_between_neighbors  \
# 0                             0.136478                        -0.011510
# 1                             0.025149                        -0.022514
# 2                            -0.012601                        -0.135272
# 3                            -0.145169                        -0.065281
# 4                             0.104752                        -0.039316
# ...                                ...                              ...
# 5294                          0.020026                         0.016863
# 5295                          0.137272                        -0.036525
# 5296                          0.057305                        -0.053405
# 5297                         -0.024593                         0.027337
# 5298                         -0.068031                        -0.005585
#
#       cell_first_neighbor_distance  cell_second_neighbor_distance  \
# 0                         0.091766                       0.124078
# 1                         0.037120                       0.007819
# 2                        -0.040547                      -0.026865
# 3                        -0.147144                      -0.128533
# 4                         0.046209                       0.143285
# ...                            ...                            ...
# 5294                      0.040476                       0.005527
# 5295                      0.136140                       0.114546
# 5296                      0.080695                       0.081449
# 5297                      0.009884                      -0.012264
# 5298                     -0.065405                      -0.062405
#
#       cell_angle_between_neighbors  cytoplasm_first_neighbor_distance  \
# 0                         0.002455                           0.067050
# 1                        -0.033004                           0.018653
# 2                        -0.130039                          -0.002738
# 3                        -0.035737                          -0.126620
# 4                        -0.026073                           0.074235
# ...                            ...                                ...
# 5294                     -0.004402                           0.037376
# 5295                     -0.018593                           0.191812
# 5296                      0.011527                           0.057014
# 5297                      0.025457                          -0.020282
# 5298                     -0.010402                          -0.082772
#
#       cytoplasm_second_neighbor_distance  cytoplasm_angle_between_neighbors
# 0                               0.097289                          -0.029682
# 1                               0.018123                          -0.036049
# 2                               0.030603                          -0.073141
# 3                              -0.148200                          -0.029065
# 4                               0.161979                          -0.064552
# ...                                  ...                                ...
# 5294                            0.038317                           0.002750
# 5295                            0.176152                          -0.046862
# 5296                            0.050908                          -0.035474
# 5297                            0.033603                          -0.014498
# 5298                           -0.110535                           0.005846
#
# [5299 rows x 1432 columns]

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Principal Component Analysis
#
# - `CUM_VAR_THRESHOLD`: Minimum cumulative variance that needs to be explained by selected PCA features. Higher variance = more features.

# %%
CUM_VAR_THRESHOLD = 0.99
LEIDEN_RESOLUTION = 5

# %%
CONTROL_PREFIX = config["aggregate"]["control_prefix"]
POPULATION_FEATURE = config["aggregate"]["population_feature"]

# normalize filtered data
normalized_data = normalize_to_controls(filtered_data, CONTROL_PREFIX)

# threshold data with pca
pca_thresholded_data, n_components, pca, fig = perform_pca_analysis(
    normalized_data, CUM_VAR_THRESHOLD
)
fig.show()

pca_thresholded_data.to_csv("/lab/barcheese01/rkern/aggregate_overhaul/compare_aggregate_methods/old_aggregate_method.tsv", sep="\t", index=False)

# perform phate leiden clustering
phate_leiden_clustering = phate_leiden_pipeline(
    pca_thresholded_data, resolution=LEIDEN_RESOLUTION
)

# create plot with phate leiden clustering
dimensionality_reduction(
    phate_leiden_clustering,
    x="PHATE_0",
    y="PHATE_1",
    control_query=f'{POPULATION_FEATURE}.str.startswith("{CONTROL_PREFIX}")',
    control_color="lightgray",
    control_legend=True,
    label_query=f'~{POPULATION_FEATURE}.str.startswith("{CONTROL_PREFIX}")',
    label_hue="cluster",
    label_palette="husl",
    s=25,
    hide_axes=False,
    label_legend=False,
    legend_kwargs={"loc": "center left", "bbox_to_anchor": (1, 0.5)},
)
# Out:
# Number of components needed for 99.0% variance: 748
# Shape of input data: (5299, 1431)
# Shape of PCA transformed and reduced data: (5299, 748)
# Calculating PHATE...
#   Running PHATE on 5299 observations and 748 variables.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 1.37 seconds.
#     Calculating KNN search...
#     Calculated KNN search in 1.85 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.15 seconds.
#   Calculated graph and diffusion operator in 3.41 seconds.
#   Calculating landmark operator...
#     Calculating SVD...
#     Calculated SVD in 1.75 seconds.
#     Calculating KMeans...
#     Calculated KMeans in 21.41 seconds.
#   Calculated landmark operator in 24.55 seconds.
#   Calculating optimal t...
#     Automatically selected t = 29
#   Calculated optimal t in 12.32 seconds.
#   Calculating diffusion potential...
#   Calculated diffusion potential in 1.64 seconds.
#   Calculating metric MDS...
#   Calculated metric MDS in 6.74 seconds.
# Calculated PHATE in 48.68 seconds.
# Number of clusters: 88
# Average cluster size: 60.22
# <Axes: xlabel='PHATE_0', ylabel='PHATE_1'>

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Cluster Analysis
#
# - `UNIPROT_DATA_FP`: Path to save and access UniProt data with gene descriptions.
# - `STRING_DATA_FP`: Path to save and access STRING data with gene pairs.
# - `CORUM_DATA_FP`: Path to save and access CORUM data with gene complexes.

# %%
UNIPROT_DATA_FP = "config/benchmark_clusters/uniprot_data.tsv"
STRING_DATA_FP = "config/benchmark_clusters/string_data.tsv"
CORUM_DATA_FP = "config/benchmark_clusters/corum_data.tsv"

# %%
# get and save uniprot data
uniprot_data = get_uniprot_data()
Path(UNIPROT_DATA_FP).parent.mkdir(parents=True, exist_ok=True)
uniprot_data.to_csv(UNIPROT_DATA_FP, sep="\t", index=False)
display(uniprot_data)

# get and save string data
string_data = get_string_data()
Path(STRING_DATA_FP).parent.mkdir(parents=True, exist_ok=True)
string_data.to_csv(STRING_DATA_FP, sep="\t", index=False)
display(string_data)

# get and save corum data
corum_data = get_corum_data()
Path(CORUM_DATA_FP).parent.mkdir(parents=True, exist_ok=True)
corum_data.to_csv(CORUM_DATA_FP, sep="\t", index=False)
display(corum_data)
# Out:
# Fetching UniProt data...
# Progress: 500 / 20417
# Progress: 1001 / 20417
# Progress: 1502 / 20417
# Progress: 2003 / 20417
# Progress: 2504 / 20417
# Progress: 3005 / 20417
# Progress: 3506 / 20417
# Progress: 4007 / 20417
# Progress: 4508 / 20417
# Progress: 5009 / 20417
# Progress: 5510 / 20417
# Progress: 6011 / 20417
# Progress: 6512 / 20417
# Progress: 7013 / 20417
# Progress: 7514 / 20417
# Progress: 8015 / 20417
# Progress: 8516 / 20417
# Progress: 9017 / 20417
# Progress: 9518 / 20417
# Progress: 10019 / 20417
# Progress: 10520 / 20417
# Progress: 11021 / 20417
# Progress: 11522 / 20417
# Progress: 12023 / 20417
# Progress: 12524 / 20417
# Progress: 13025 / 20417
# Progress: 13526 / 20417
# Progress: 14027 / 20417
# Progress: 14528 / 20417
# Progress: 15029 / 20417
# Progress: 15530 / 20417
# Progress: 16031 / 20417
# Progress: 16532 / 20417
# Progress: 17033 / 20417
# Progress: 17534 / 20417
# Progress: 18035 / 20417
# Progress: 18536 / 20417
# Progress: 19037 / 20417
# Progress: 19538 / 20417
# Progress: 20039 / 20417
# Progress: 20457 / 20417
# Completed. Total entries: 20457
#                                Gene Names  \
# 0                                 MT-RNR1
# 1                             CIROP LMLN2
# 2       BLTP3B KIAA0701 SHIP164 UHRF1BP1L
# 3                                  POTEB3
# 4                                   CLRN2
# ...                                   ...
# 20452                   LINC00597 C15orf5
# 20453                             PRO3102
# 20454                             PRO2829
# 20455
# 20456  LINC00312 LOH3CR2A NCRNA00312 NAG7
#
#                                            Function [CC]            KEGG  \
# 0      FUNCTION: Regulates insulin sensitivity and me...
# 1      FUNCTION: Putative metalloproteinase that play...
# 2      FUNCTION: Tube-forming lipid transport protein...      hsa:23074;
# 3                                                         hsa:102724631;
# 4      FUNCTION: Plays a key role to hearing function...     hsa:645104;
# ...                                                  ...             ...
# 20452
# 20453
# 20454
# 20455
# 20456
#
#       ComplexPortal                 STRING
# 0
# 1
# 2                    9606.ENSP00000279907;
# 3                    9606.ENSP00000483103;
# 4                    9606.ENSP00000424711;
# ...             ...                    ...
# 20452
# 20453
# 20454
# 20455
# 20456
#
# [20457 rows x 5 columns]
# Fetching STRING data...
# Completed. Total interactions: 117118
#                       protein1              protein2  combined_score
# 160       9606.ENSP00000000233  9606.ENSP00000262305             952
# 1396      9606.ENSP00000000412  9606.ENSP00000438085             993
# 1583      9606.ENSP00000000412  9606.ENSP00000371175             957
# 1601      9606.ENSP00000000412  9606.ENSP00000349437             991
# 1780      9606.ENSP00000001008  9606.ENSP00000351646             979
# ...                        ...                   ...             ...
# 13714840  9606.ENSP00000501277  9606.ENSP00000268679             991
# 13714879  9606.ENSP00000501277  9606.ENSP00000294339             999
# 13714880  9606.ENSP00000501277  9606.ENSP00000264824             968
# 13715299  9606.ENSP00000501317  9606.ENSP00000305071             978
# 13715301  9606.ENSP00000501317  9606.ENSP00000296785             973
#
# [117118 rows x 3 columns]
# Fetching CORUM data...
# /lab/barcheese01/rkern/miniconda3/envs/brieflow_denali_env/lib/python3.11/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mips.helmholtz-muenchen.de'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Completed. Total complexes: 5366
#       complex_id                           complex_name  \
# 0              1                     BCL6-HDAC4 complex
# 1              2                     BCL6-HDAC5 complex
# 2              3                     BCL6-HDAC7 complex
# 3              4  Multisubunit ACTR coactivator complex
# 4             10                    Condensin I complex
# ...          ...                                    ...
# 5361       11423                    DRD5-NPFFR1 complex
# 5362       11424                    DRD1-NPFFR2 complex
# 5363       11425                   HCRTR1-QRFPR complex
# 5364       11426                     LRP4-SOST complex
# 5365       11427                   HCRTR2-QRFPR complex
#
#                    synonyms organism  \
# 0                       NaN    Human
# 1                       NaN    Human
# 2                       NaN    Human
# 3                       NaN    Human
# 4     13S condensin complex    Human
# ...                     ...      ...
# 5361                    NaN    Human
# 5362                    NaN    Human
# 5363    OX1R-GPR103 complex    Human
# 5364                    NaN    Human
# 5365    OX2R-GPR103 complex    Human
#
#                                           cell_line      pmid  \
# 0             U2OS osteosarcoma-derived UTA-L cells  11929873
# 1             U2OS osteosarcoma-derived UTA-L cells  11929873
# 2             U2OS osteosarcoma-derived UTA-L cells  11929873
# 3     different human tissues and cancer cell lines   9267036
# 4                                        HeLa cells  11136719
# ...                                             ...       ...
# 5361                   renal proximal tubule cells   38965251
# 5362                   renal proximal tubule cells   38965251
# 5363                    HEK293 cells; HEK293T cells  26223541
# 5364                                   HEK293 cells  21471202
# 5365                    HEK293 cells; HEK293T cells  26223541
#
#                                         comment_complex comment_members  \
# 0     Transcriptional repression by BCL6 is thought ...             NaN
# 1     Transcriptional repression by BCL6 is thought ...             NaN
# 2     Transcriptional repression by BCL6 is thought ...             NaN
# 3     Cofactor ACTR binds directly nuclear receptors...             NaN
# 4                                                   NaN             NaN
# ...                                                 ...             ...
# 5361  The kidney and brain play critical roles in th...             NaN
# 5362  The kidney and brain play critical roles in th...             NaN
# 5363  Orexins are neuropeptides that regulate the sl...             NaN
# 5364  SOST (Sclerostin)-mediated inhibition of Wnt1/...             NaN
# 5365  Orexins are neuropeptides that regulate the sl...             NaN
#
#                                         comment_disease comment_drug  ...  \
# 0                                                   NaN          NaN  ...
# 1                                                   NaN          NaN  ...
# 2                                                   NaN          NaN  ...
# 3                                                   NaN          NaN  ...
# 4                                                   NaN          NaN  ...
# ...                                                 ...          ...  ...
# 5361                                                NaN          NaN  ...
# 5362                                                NaN          NaN  ...
# 5363  Alzheimer's disease (AD) patients experience i...          NaN  ...
# 5364                                                NaN          NaN  ...
# 5365  Alzheimer's disease (AD) patients experience i...          NaN  ...
#
#                                       functions_go_name  \
# 0     histone deacetylase activity;nucleus;DNA topol...
# 1     histone deacetylase activity;nucleus;DNA topol...
# 2     histone deacetylase activity;nucleus;DNA topol...
# 3     histone acetyltransferase activity;nuclear rec...
# 4     mitotic cell cycle;M phase;chromosome;chromoso...
# ...                                                 ...
# 5361  G protein-coupled receptor signaling pathway;G...
# 5362  G protein-coupled receptor signaling pathway;G...
# 5363  G protein-coupled receptor signaling pathway;n...
# 5364  negative regulation of canonical Wnt signaling...
# 5365  G protein-coupled receptor signaling pathway;n...
#
#                                   functions_go_ontology fcgs_description  \
# 0     molecular_function;cellular_component;biologic...              NaN
# 1     molecular_function;cellular_component;biologic...              NaN
# 2     molecular_function;cellular_component;biologic...              NaN
# 3                 molecular_function;molecular_function              NaN
# 4     biological_process;biological_process;cellular...              NaN
# ...                                                 ...              ...
# 5361  biological_process;biological_process;biologic...                ;
# 5362  biological_process;biological_process;biologic...                ;
# 5363  biological_process;biological_process;biologic...                ;
# 5364                                 biological_process              NaN
# 5365  biological_process;biological_process;biologic...                ;
#
#      fcgs_id                                          fcgs_name  \
# 0        NaN                                                NaN
# 1        NaN                                                NaN
# 2        NaN                                                NaN
# 3        NaN                                                NaN
# 4        NaN                                                NaN
# ...      ...                                                ...
# 5361   20;24  G protein-coupled receptor signaling pathway;R...
# 5362   20;24  G protein-coupled receptor signaling pathway;R...
# 5363   44;20  Energy homeostasis;G protein-coupled receptor ...
# 5364     NaN                                                NaN
# 5365   44;20  Energy homeostasis;G protein-coupled receptor ...
#
#      fcgs_category_id                                 fcgs_category_name  \
# 0                 NaN                                                NaN
# 1                 NaN                                                NaN
# 2                 NaN                                                NaN
# 3                 NaN                                                NaN
# 4                 NaN                                                NaN
# ...               ...                                                ...
# 5361              6;7  Signaling molecules and interaction;System pro...
# 5362              6;7  Signaling molecules and interaction;System pro...
# 5363              8;6  Metabolic process;Signaling molecules and inte...
# 5364              NaN                                                NaN
# 5365              8;6  Metabolic process;Signaling molecules and inte...
#
#                  fcgs_go_id  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 5361  GO:0007186;GO:0008217
# 5362  GO:0007186;GO:0008217
# 5363  GO:0097009;GO:0007186
# 5364                    NaN
# 5365  GO:0097009;GO:0007186
#
#                                            fcgs_go_name  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5361  G protein-coupled receptor signaling pathway;r...
# 5362  G protein-coupled receptor signaling pathway;r...
# 5363  energy homeostasis;G protein-coupled receptor ...
# 5364                                                NaN
# 5365  energy homeostasis;G protein-coupled receptor ...
#
#                            fcgs_go_ontology
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 5361  biological_process;biological_process
# 5362  biological_process;biological_process
# 5363  biological_process;biological_process
# 5364                                    NaN
# 5365  biological_process;biological_process
#
# [5366 rows x 34 columns]

# %%
# load cluster data with uniprot annotations
phate_leiden_uniprot = merge_phate_uniprot(phate_leiden_clustering, UNIPROT_DATA_FP)

# create cluster gene table
cluster_gene_table = create_cluster_gene_table(
    phate_leiden_uniprot,
    columns_to_combine=[POPULATION_FEATURE, "STRING"],
)

# analyze differential features
cluster_gene_table, diff_results = analyze_differential_features(
    cluster_gene_table, cleaned_data
)

# process interactions and get enrichment results
cluster_gene_table, global_metrics = process_interactions(
    cluster_gene_table, STRING_DATA_FP, CORUM_DATA_FP
)

# show cluster analysis results
display(cluster_gene_table)
display(global_metrics)
# Out:
# Analyzing 88 clusters...
# Processing cluster 48/88 (#47)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 11
#       5 cluster_gene_table = create_cluster_gene_table(
#       6     phate_leiden_uniprot,
#       7     columns_to_combine=[POPULATION_FEATURE, "STRING"],
#       8 )
#      10 # analyze differential features
# ---> 11 cluster_gene_table, diff_results = analyze_differential_features(
#      12     cluster_gene_table, cleaned_data
#      13 )
#      15 # process interactions and get enrichment results
#      16 cluster_gene_table, global_metrics = process_interactions(
#      17     cluster_gene_table, STRING_DATA_FP, CORUM_DATA_FP
#      18 )
#
# File /lab/cheeseman_ops/brieflow-screens/denali-analysis/brieflow/workflow/lib/cluster/benchmark_clusters.py:112, in analyze_differential_features(cluster_gene_table, feature_df, n_top, exclude_cols)
#     110 # Calculate t-statistic, p-value, and effect size for each feature
#     111 for feature in feature_cols:
# --> 112     t_stat, p_val = ttest_ind(cluster_data[feature], non_cluster_data[feature])
#     113     cohens_d = (
#     114         cluster_data[feature].mean() - non_cluster_data[feature].mean()
#     115     ) / np.sqrt(
#    (...)    122         )
#     123     )
#     125     # Store results
#
# File /lab/barcheese01/rkern/miniconda3/envs/brieflow_denali_env/lib/python3.11/site-packages/scipy/_lib/deprecation.py:234, in _deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     232 if extra_args <= 0:
#     233     warn_deprecated_args(kwargs)
# --> 234     return f(*args, **kwargs)
#     236 # extra_args > 0
#     237 kwonly_extra_args = set(kwonly_args[:extra_args]) - deprecated_args
#
# File /lab/barcheese01/rkern/miniconda3/envs/brieflow_denali_env/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:586, in _axis_nan_policy_factory.<locals>.axis_nan_policy_decorator.<locals>.axis_nan_policy_wrapper(***failed resolving arguments***)
#     583     res = _add_reduced_axes(res, reduced_axes, keepdims)
#     584     return tuple_to_result(*res)
# --> 586 res = hypotest_fun_out(*samples, **kwds)
#     587 res = result_to_tuple(res, n_out)
#     588 res = _add_reduced_axes(res, reduced_axes, keepdims)
#
# File /lab/barcheese01/rkern/miniconda3/envs/brieflow_denali_env/lib/python3.11/site-packages/scipy/stats/_stats_py.py:6679, in ttest_ind(a, b, axis, equal_var, nan_policy, permutations, random_state, alternative, trim, method)
#    6677 if trim == 0:
#    6678     with np.errstate(divide='ignore', invalid='ignore'):
# -> 6679         v1 = _var(a, axis, ddof=1, xp=xp)
#    6680         v2 = _var(b, axis, ddof=1, xp=xp)
#    6682     m1 = xp.mean(a, axis=axis)
#
# File /lab/barcheese01/rkern/miniconda3/envs/brieflow_denali_env/lib/python3.11/site-packages/scipy/stats/_stats_py.py:1211, in _var(x, axis, ddof, mean, xp)
#    1208 def _var(x, axis=0, ddof=0, mean=None, xp=None):
#    1209     # Calculate variance of sample, warning if precision is lost
#    1210     xp = array_namespace(x) if xp is None else xp
# -> 1211     var = _moment(x, 2, axis, mean=mean, xp=xp)
#    1212     if ddof != 0:
#    1213         n = x.shape[axis] if axis is not None else xp_size(x)
#
# File /lab/barcheese01/rkern/miniconda3/envs/brieflow_denali_env/lib/python3.11/site-packages/scipy/stats/_stats_py.py:1205, in _moment(a, order, axis, mean, xp)
#    1203     if n % 2:
#    1204         s *= a_zero_mean
# -> 1205 return xp.mean(s, axis=axis)
#
# File /lab/barcheese01/rkern/miniconda3/envs/brieflow_denali_env/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3504, in mean(a, axis, dtype, out, keepdims, where)
#    3501     else:
#    3502         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3504 return _methods._mean(a, axis=axis, dtype=dtype,
#    3505                       out=out, **kwargs)
#
# File /lab/barcheese01/rkern/miniconda3/envs/brieflow_denali_env/lib/python3.11/site-packages/numpy/core/_methods.py:112, in _mean(a, axis, dtype, out, keepdims, where)
#     110 # Cast bool, unsigned int, and int to float64 by default
#     111 if dtype is None:
# --> 112     if issubclass(arr.dtype.type, (nt.integer, nt.bool_)):
#     113         dtype = mu.dtype('f8')
#     114     elif issubclass(arr.dtype.type, nt.float16):
#
# KeyboardInterrupt:

# %% [markdown]
# ## Add cluster parameters to config file

# %%
# Add cluster section
config["cluster"] = {
    "channel_combos": CHANNEL_COMBOS,
    "dataset_types": DATASET_TYPES,
    "min_cell_cutoffs": MIN_CELL_CUTOFFS,
    "correlation_threshold": CORRELATION_THRESHOLD,
    "variance_threshold": VARIANCE_THRESHOLD,
    "min_unique_values": MIN_UNIQUE_VALUES,
    "cum_var_threshold": CUM_VAR_THRESHOLD,
    "leiden_resolution": LEIDEN_RESOLUTION,
    "uniprot_data_fp": UNIPROT_DATA_FP,
    "string_data_fp": STRING_DATA_FP,
    "corum_data_fp": CORUM_DATA_FP,
}

# Write the updated configuration
with open(CONFIG_FILE_PATH, "w") as config_file:
    # Write the introductory comments
    config_file.write(CONFIG_FILE_HEADER)

    # Dump the updated YAML structure, keeping markdown comments for sections
    yaml.dump(config, config_file, default_flow_style=False)
