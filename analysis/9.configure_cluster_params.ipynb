# %% [markdown]
# # Configure Cluster Module Params
#
# This notebook should be used as a test for ensuring correct cluster parameters before cluster processing.
# Cells marked with <font color='red'>SET PARAMETERS</font> contain crucial variables that need to be set according to your specific experimental setup and data organization.
# Please review and modify these variables as needed before proceeding with the analysis.

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Fixed parameters for cluster module
#
# - `CONFIG_FILE_PATH`: Path to a Brieflow config file used during processing. Absolute or relative to where workflows are run from.

# %%
CONFIG_FILE_PATH = "config/config.yml"

# %%
from pathlib import Path

import yaml
import pandas as pd
from matplotlib import pyplot as plt

from lib.cluster.cluster_eval import plot_cell_histogram
from lib.cluster.generate_dataset import (
    clean_and_validate,
    split_channels,
    remove_low_number_genes,
    remove_missing_features,
)
from lib.cluster.phate_leiden_clustering import (
    select_features,
    normalize_to_controls,
    perform_pca_analysis,
    phate_leiden_pipeline,
    dimensionality_reduction,
    merge_phate_uniprot,
)
from lib.cluster.benchmark_clusters import (
    create_cluster_gene_table,
    analyze_differential_features,
    process_interactions,
)
from lib.cluster.scrape_benchmarks import (
    get_uniprot_data,
    get_string_data,
    get_corum_data,
)
from lib.shared.configuration_utils import CONFIG_FILE_HEADER

# %%
# load config file and determine root path
with open(CONFIG_FILE_PATH, "r") as config_file:
    config = yaml.safe_load(config_file)
    ROOT_FP = Path(config["all"]["root_fp"])

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Cluster processing
#
# - `CHANNEL_COMBOS`: Combinations of channels to use during cluster process.
# - `DATASET_TYPES`: Dataset types to use during cluster process; created during the aggregate process.
# - `MIN_CELL_CUTOFFS`: Minimum cells for each gene to be used in clusetering analysis. More cells per gene increases confidence, but some dataset types (ex mitotic) may have an inherently low number of cells for a particular perturbation.

# %%
# parameters for all cluster processing
CHANNEL_COMBOS = [
    ["DAPI", "COXIV", "CENPA", "WGA"],
    ["DAPI", "CENPA"],
]
DATASET_TYPES = ["mitotic", "interphase", "all"]
MIN_CELL_CUTOFFS = {"mitotic": 0, "interphase": 3, "all": 3}

# %%
for dataset_type, min_cell_cutoff in MIN_CELL_CUTOFFS.items():
    # load and clean relevant dataset
    gene_data_fp = ROOT_FP / "aggregate" / "tsvs" / f"{dataset_type}_gene_data.tsv"
    gene_data = pd.read_csv(gene_data_fp, sep="\t")
    cleaned_data = clean_and_validate(gene_data)

    # show cell count distribution
    print(f"Cell count distribution for: {dataset_type}")
    plot_cell_histogram(cleaned_data, min_cell_cutoff)
    plt.show()
# Out:
# Cell count distribution for: mitotic
# Number of genes below cutoff: 0
# []
# Cell count distribution for: interphase
# Number of genes below cutoff: 3
# ['nontargeting_149', 'nontargeting_210', 'nontargeting_220']
# Cell count distribution for: all
# Number of genes below cutoff: 3
# ['nontargeting_149', 'nontargeting_210', 'nontargeting_220']

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Cluster testing
#
# - `TEST_CHANNEL_COMBO`: Channel combination to use for testing cluster process. Should be smallest or most relevant channel combination.
# - `TEST_DATASET_TYPE`: Dataset type to use for testing cluster process. Should be smallest or most relevant dataset type.

# %%
# parameters for testing cluster processing
TEST_CHANNEL_COMBO = ["DAPI", "CENPA"]
TEST_DATASET_TYPE = "mitotic"

# %%
# load gene data based on dataset we are processing
gene_data_fp = ROOT_FP / "aggregate" / "tsvs" / f"{TEST_DATASET_TYPE}_gene_data.tsv"
gene_data = pd.read_csv(gene_data_fp, sep="\t")

# clean and validate gene data
validated_data = clean_and_validate(gene_data)

# filter dataset for channels of interest
channel_filtered_data = split_channels(
    validated_data,
    TEST_CHANNEL_COMBO,
    config["phenotype"]["channel_names"],
)

# clean low number genes and missing features
cleaned_data = remove_low_number_genes(
    channel_filtered_data, MIN_CELL_CUTOFFS[TEST_DATASET_TYPE]
)
cleaned_data = remove_missing_features(cleaned_data)

cleaned_data
# Out:
# Gene Filtering Summary:
# Original genes: 4943
# Genes with < 0 cells: 0
# Remaining genes: 4943
#
# Feature Cleaning Summary:
# Original features: 887
#
# Removed features:
#
# Features with infinite values (35):
# - nucleus_DAPI_pftas_7
# - nucleus_DAPI_pftas_8
# - nucleus_DAPI_pftas_15
# - nucleus_DAPI_pftas_16
# - nucleus_DAPI_pftas_17
# - nucleus_DAPI_pftas_24
# - nucleus_DAPI_pftas_25
# - nucleus_DAPI_pftas_26
# - nucleus_DAPI_pftas_34
# - nucleus_DAPI_pftas_35
# - nucleus_DAPI_pftas_42
# - nucleus_DAPI_pftas_43
# - nucleus_DAPI_pftas_44
# - nucleus_DAPI_pftas_52
# - nucleus_DAPI_pftas_53
# - cell_DAPI_pftas_7
# - cell_DAPI_pftas_8
# - cell_DAPI_pftas_15
# - cell_DAPI_pftas_16
# - cell_DAPI_pftas_17
# - cell_DAPI_pftas_24
# - cell_DAPI_pftas_25
# - cell_DAPI_pftas_26
# - cell_DAPI_pftas_34
# - cell_DAPI_pftas_35
# - cell_DAPI_pftas_42
# - cell_DAPI_pftas_43
# - cell_DAPI_pftas_51
# - cell_DAPI_pftas_52
# - cell_DAPI_pftas_53
# - cytoplasm_DAPI_pftas_15
# - cytoplasm_DAPI_pftas_34
# - cytoplasm_DAPI_pftas_35
# - cytoplasm_DAPI_pftas_43
# - cytoplasm_DAPI_pftas_53
#
# Features with null/NA values (99):
# - nucleus_CENPA_haralick_5_0
# - nucleus_CENPA_haralick_5_1
# - nucleus_CENPA_haralick_5_2
# - nucleus_CENPA_haralick_5_3
# - nucleus_CENPA_haralick_5_4
# - nucleus_CENPA_haralick_5_5
# - nucleus_CENPA_haralick_5_6
# - nucleus_CENPA_haralick_5_7
# - nucleus_CENPA_haralick_5_8
# - nucleus_CENPA_haralick_5_9
# - nucleus_CENPA_haralick_5_10
# - nucleus_CENPA_haralick_5_11
# - nucleus_CENPA_haralick_5_12
# - nucleus_euler_number
# - cell_DAPI_pftas_44
# - cell_CENPA_haralick_5_0
# - cell_CENPA_haralick_5_1
# - cell_CENPA_haralick_5_2
# - cell_CENPA_haralick_5_3
# - cell_CENPA_haralick_5_4
# - cell_CENPA_haralick_5_5
# - cell_CENPA_haralick_5_6
# - cell_CENPA_haralick_5_7
# - cell_CENPA_haralick_5_8
# - cell_CENPA_haralick_5_9
# - cell_CENPA_haralick_5_10
# - cell_CENPA_haralick_5_11
# - cell_CENPA_haralick_5_12
# - cell_euler_number
# - cytoplasm_DAPI_frac_at_d_0
# - cytoplasm_CENPA_frac_at_d_0
# - cytoplasm_DAPI_frac_at_d_1
# - cytoplasm_CENPA_frac_at_d_1
# - cytoplasm_DAPI_mean_frac_0
# - cytoplasm_CENPA_mean_frac_0
# - cytoplasm_DAPI_mean_frac_1
# - cytoplasm_CENPA_mean_frac_1
# - cytoplasm_DAPI_mean_frac_2
# - cytoplasm_CENPA_mean_frac_2
# - cytoplasm_DAPI_radial_cv_0
# - cytoplasm_CENPA_radial_cv_0
# - cytoplasm_DAPI_radial_cv_1
# - cytoplasm_CENPA_radial_cv_1
# - cytoplasm_DAPI_radial_cv_2
# - cytoplasm_CENPA_radial_cv_2
# - cytoplasm_DAPI_pftas_6
# - cytoplasm_DAPI_pftas_7
# - cytoplasm_DAPI_pftas_8
# - cytoplasm_CENPA_pftas_8
# - cytoplasm_DAPI_pftas_16
# - cytoplasm_DAPI_pftas_17
# - cytoplasm_DAPI_pftas_23
# - cytoplasm_DAPI_pftas_24
# - cytoplasm_DAPI_pftas_25
# - cytoplasm_DAPI_pftas_26
# - cytoplasm_CENPA_pftas_26
# - cytoplasm_DAPI_pftas_27
# - cytoplasm_DAPI_pftas_28
# - cytoplasm_DAPI_pftas_36
# - cytoplasm_DAPI_pftas_44
# - cytoplasm_DAPI_pftas_45
# - cytoplasm_DAPI_pftas_46
# - cytoplasm_DAPI_pftas_47
# - cytoplasm_DAPI_pftas_48
# - cytoplasm_DAPI_haralick_5_0
# - cytoplasm_CENPA_haralick_5_0
# - cytoplasm_DAPI_haralick_5_1
# - cytoplasm_CENPA_haralick_5_1
# - cytoplasm_DAPI_haralick_5_2
# - cytoplasm_CENPA_haralick_5_2
# - cytoplasm_DAPI_haralick_5_3
# - cytoplasm_CENPA_haralick_5_3
# - cytoplasm_DAPI_haralick_5_4
# - cytoplasm_CENPA_haralick_5_4
# - cytoplasm_DAPI_haralick_5_5
# - cytoplasm_CENPA_haralick_5_5
# - cytoplasm_DAPI_haralick_5_6
# - cytoplasm_CENPA_haralick_5_6
# - cytoplasm_DAPI_haralick_5_7
# - cytoplasm_CENPA_haralick_5_7
# - cytoplasm_DAPI_haralick_5_8
# - cytoplasm_CENPA_haralick_5_8
# - cytoplasm_DAPI_haralick_5_9
# - cytoplasm_CENPA_haralick_5_9
# - cytoplasm_DAPI_haralick_5_10
# - cytoplasm_CENPA_haralick_5_10
# - cytoplasm_DAPI_haralick_5_11
# - cytoplasm_CENPA_haralick_5_11
# - cytoplasm_DAPI_haralick_5_12
# - cytoplasm_CENPA_haralick_5_12
# - cytoplasm_euler_number
# - cell_CENPA_foci_count
# - cell_CENPA_foci_area
# - nucleus_number_neighbors_1
# - nucleus_percent_touching_1
# - cell_number_neighbors_1
# - cell_percent_touching_1
# - cytoplasm_number_neighbors_1
# - cytoplasm_percent_touching_1
#
# Remaining features: 753
#         gene_symbol_0  cell_number  nucleus_DAPI_mean  nucleus_CENPA_mean  \
# 0                AAAS           11           0.746909            0.497419
# 1               AAGAB           15           0.200649           -0.042500
# 2                AAK1            5          -0.382372           -0.513930
# 3                AAMP            3          -0.295839           -0.169094
# 4               AARS1            9          -0.097624            0.497584
# ...               ...          ...                ...                 ...
# 4938  nontargeting_95            1          -0.505169           -0.538492
# 4939  nontargeting_96            1           1.240999           14.948891
# 4940  nontargeting_97            2           0.294694            1.859946
# 4941  nontargeting_98            1          -0.257582           -0.310679
# 4942  nontargeting_99            3          -0.027776            0.001242
#
#       nucleus_DAPI_std  nucleus_CENPA_std  nucleus_DAPI_max  \
# 0            -0.141563           0.504267          0.475943
# 1             0.346509          -0.219333          0.371179
# 2            -0.367707          -0.115677         -0.424017
# 3            -1.312422           0.260812         -1.222473
# 4             0.354845           0.235389          0.541765
# ...                ...                ...               ...
# 4938         -0.440861          -0.414092         -0.685970
# 4939         -2.547788           5.455721         -1.215988
# 4940         -0.858910           1.741407         -0.333508
# 4941          0.030688          -0.997602         -0.241111
# 4942         -0.175096           0.490338         -0.105047
#
#       nucleus_CENPA_max  nucleus_DAPI_min  nucleus_CENPA_min  ...  \
# 0              0.298549          0.805117           0.398568  ...
# 1             -0.182732         -0.218464          -0.153295  ...
# 2             -0.409558         -0.635007          -0.075401  ...
# 3              0.221468          1.447061           0.055417  ...
# 4              0.102890          1.075529           0.483088  ...
# ...                 ...               ...                ...  ...
# 4938          -0.608254         -0.434545          -0.382217  ...
# 4939          15.026975          9.355606          15.943616  ...
# 4940           2.328287          1.520766           1.739075  ...
# 4941          -0.564825         -0.837237          -0.385429  ...
# 4942           0.090335         -0.069467          -0.420341  ...
#
#       cytoplasm_bounds_3  nucleus_first_neighbor_distance  \
# 0              -0.157693                        -0.059831
# 1               0.160489                         0.257574
# 2               0.333027                         0.539456
# 3               1.072426                        -0.371836
# 4               0.742740                         0.863738
# ...                  ...                              ...
# 4938           -0.187422                         0.321811
# 4939            0.742241                         1.558720
# 4940           -0.644096                         1.648817
# 4941            0.572464                        -0.281974
# 4942            1.295994                        -0.171135
#
#       nucleus_second_neighbor_distance  nucleus_angle_between_neighbors  \
# 0                             0.179279                         0.250149
# 1                             0.034351                         0.153169
# 2                             0.718742                        -0.285034
# 3                            -0.422222                         0.575548
# 4                             0.461714                        -0.012796
# ...                                ...                              ...
# 4938                          0.246110                        -0.523196
# 4939                          1.008858                        -0.112455
# 4940                          1.159115                         0.642444
# 4941                          0.731467                        -0.194521
# 4942                          0.590701                        -0.991455
#
#       cell_first_neighbor_distance  cell_second_neighbor_distance  \
# 0                        -0.016067                       0.448217
# 1                         0.323075                       0.199006
# 2                         0.517559                       0.663341
# 3                        -0.343454                      -0.386439
# 4                         0.592004                       0.508674
# ...                            ...                            ...
# 4938                      0.549881                      -0.040509
# 4939                      1.850068                       1.071752
# 4940                      1.734344                       1.167947
# 4941                     -0.301481                       0.687252
# 4942                      0.109084                       0.844683
#
#       cell_angle_between_neighbors  cytoplasm_first_neighbor_distance  \
# 0                         0.501024                           0.004811
# 1                         0.094623                           0.143274
# 2                        -0.165276                           0.288604
# 3                         0.467061                          -0.363691
# 4                        -0.717603                           0.377870
# ...                            ...                                ...
# 4938                     -0.455598                           0.566649
# 4939                     -0.104467                           1.994079
# 4940                      0.842704                           1.236001
# 4941                     -0.083022                          -0.112297
# 4942                     -0.724194                           0.292345
#
#       cytoplasm_second_neighbor_distance  cytoplasm_angle_between_neighbors
# 0                               0.693398                           0.614003
# 1                               0.261583                          -0.272373
# 2                               0.759959                          -0.372807
# 3                              -0.319792                           1.027324
# 4                               0.617180                           0.275063
# ...                                  ...                                ...
# 4938                           -0.468550                          -0.543585
# 4939                            0.723460                          -0.008160
# 4940                            1.568578                           0.892906
# 4941                            0.457087                           0.003095
# 4942                            0.872575                          -0.759526
#
# [4943 rows x 753 columns]

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Feature selection
#
# - `CORRELATION_THRESHOLD`: Features with a correlation (to another feature) above this threshold are iteratively removed to get "unique" features.
# - `VARIANCE_THRESHOLD`: Features with variance below this threshold are removed.
# - `MIN_UNIQUE_VALUES`: Features with a number of unique values below this threshold are removed.

# %%
# parameters used for feature selection
CORRELATION_THRESHOLD = 0.99
VARIANCE_THRESHOLD = 0.001
MIN_UNIQUE_VALUES = 5

# %%
# select features
filtered_data, removed_features = select_features(
    cleaned_data,
    correlation_threshold=CORRELATION_THRESHOLD,
    variance_threshold=VARIANCE_THRESHOLD,
    min_unique_values=MIN_UNIQUE_VALUES,
)

filtered_data
# Out:
# Feature Selection Summary:
# Original features: 751
# Features removed due to correlation: 100
# Features removed due to low variance: 0
# Features removed due to few unique values: 0
# Final features: 651
#         gene_symbol_0  nucleus_DAPI_mean  nucleus_DAPI_std  nucleus_CENPA_std  \
# 0                AAAS           0.746909         -0.141563           0.504267
# 1               AAGAB           0.200649          0.346509          -0.219333
# 2                AAK1          -0.382372         -0.367707          -0.115677
# 3                AAMP          -0.295839         -1.312422           0.260812
# 4               AARS1          -0.097624          0.354845           0.235389
# ...               ...                ...               ...                ...
# 4938  nontargeting_95          -0.505169         -0.440861          -0.414092
# 4939  nontargeting_96           1.240999         -2.547788           5.455721
# 4940  nontargeting_97           0.294694         -0.858910           1.741407
# 4941  nontargeting_98          -0.257582          0.030688          -0.997602
# 4942  nontargeting_99          -0.027776         -0.175096           0.490338
#
#       nucleus_CENPA_max  nucleus_DAPI_int_edge  nucleus_CENPA_int_edge  \
# 0              0.298549               0.244525                0.123548
# 1             -0.182732               0.224967                0.331556
# 2             -0.409558              -0.185631                0.131793
# 3              0.221468               0.522096               -0.517342
# 4              0.102890               0.688790                0.641665
# ...                 ...                    ...                     ...
# 4938          -0.608254               0.499343                0.462051
# 4939          15.026975              15.218844               40.497191
# 4940           2.328287               1.363185                1.627395
# 4941          -0.564825              -0.553364                0.524931
# 4942           0.090335              -0.877449               -0.616379
#
#       nucleus_DAPI_mean_edge  nucleus_DAPI_std_edge  nucleus_CENPA_std_edge  \
# 0                   0.215819               0.143530                0.223127
# 1                   0.276571               0.247348                0.216218
# 2                  -0.501865               0.533008               -0.598627
# 3                   1.368655              -0.173162               -0.733771
# 4                   0.711620              -0.417483                0.680103
# ...                      ...                    ...                     ...
# 4938               -0.331527               0.027788                0.005946
# 4939                7.913156               0.367140                5.146837
# 4940                1.489716              -0.756598                2.377418
# 4941               -1.020142               0.485556               -0.016527
# 4942               -0.669971              -0.230059                0.363283
#
#       ...  cytoplasm_zernike_9_9  nucleus_first_neighbor_distance  \
# 0     ...               0.070268                        -0.059831
# 1     ...               0.563787                         0.257574
# 2     ...               0.566293                         0.539456
# 3     ...               0.368787                        -0.371836
# 4     ...              -0.346934                         0.863738
# ...   ...                    ...                              ...
# 4938  ...               0.016991                         0.321811
# 4939  ...               0.352349                         1.558720
# 4940  ...              -0.088313                         1.648817
# 4941  ...               0.890922                        -0.281974
# 4942  ...               0.194711                        -0.171135
#
#       nucleus_second_neighbor_distance  nucleus_angle_between_neighbors  \
# 0                             0.179279                         0.250149
# 1                             0.034351                         0.153169
# 2                             0.718742                        -0.285034
# 3                            -0.422222                         0.575548
# 4                             0.461714                        -0.012796
# ...                                ...                              ...
# 4938                          0.246110                        -0.523196
# 4939                          1.008858                        -0.112455
# 4940                          1.159115                         0.642444
# 4941                          0.731467                        -0.194521
# 4942                          0.590701                        -0.991455
#
#       cell_first_neighbor_distance  cell_second_neighbor_distance  \
# 0                        -0.016067                       0.448217
# 1                         0.323075                       0.199006
# 2                         0.517559                       0.663341
# 3                        -0.343454                      -0.386439
# 4                         0.592004                       0.508674
# ...                            ...                            ...
# 4938                      0.549881                      -0.040509
# 4939                      1.850068                       1.071752
# 4940                      1.734344                       1.167947
# 4941                     -0.301481                       0.687252
# 4942                      0.109084                       0.844683
#
#       cell_angle_between_neighbors  cytoplasm_first_neighbor_distance  \
# 0                         0.501024                           0.004811
# 1                         0.094623                           0.143274
# 2                        -0.165276                           0.288604
# 3                         0.467061                          -0.363691
# 4                        -0.717603                           0.377870
# ...                            ...                                ...
# 4938                     -0.455598                           0.566649
# 4939                     -0.104467                           1.994079
# 4940                      0.842704                           1.236001
# 4941                     -0.083022                          -0.112297
# 4942                     -0.724194                           0.292345
#
#       cytoplasm_second_neighbor_distance  cytoplasm_angle_between_neighbors
# 0                               0.693398                           0.614003
# 1                               0.261583                          -0.272373
# 2                               0.759959                          -0.372807
# 3                              -0.319792                           1.027324
# 4                               0.617180                           0.275063
# ...                                  ...                                ...
# 4938                           -0.468550                          -0.543585
# 4939                            0.723460                          -0.008160
# 4940                            1.568578                           0.892906
# 4941                            0.457087                           0.003095
# 4942                            0.872575                          -0.759526
#
# [4943 rows x 652 columns]

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Principal Component Analysis
#
# - `CUM_VAR_THRESHOLD`: Minimum cumulative variance that needs to be explained by selected PCA features. Higher variance = more features.

# %%
CUM_VAR_THRESHOLD = 0.99
LEIDEN_RESOLUTION = 5

# %%
CONTROL_PREFIX = config["aggregate"]["control_prefix"]
POPULATION_FEATURE = config["aggregate"]["population_feature"]

# normalize filtered data
normalized_data = normalize_to_controls(filtered_data, CONTROL_PREFIX)

# threshold data with pca
pca_thresholded_data, n_components, pca, fig = perform_pca_analysis(
    normalized_data, CUM_VAR_THRESHOLD
)
fig.show()

# perform phate leiden clustering
phate_leiden_clustering = phate_leiden_pipeline(
    pca_thresholded_data, resolution=LEIDEN_RESOLUTION
)

# create plot with phate leiden clustering
dimensionality_reduction(
    phate_leiden_clustering,
    x="PHATE_0",
    y="PHATE_1",
    control_query=f'{POPULATION_FEATURE}.str.startswith("{CONTROL_PREFIX}")',
    control_color="lightgray",
    control_legend=True,
    label_query=f'~{POPULATION_FEATURE}.str.startswith("{CONTROL_PREFIX}")',
    label_hue="cluster",
    label_palette="husl",
    s=25,
    hide_axes=False,
    label_legend=False,
    legend_kwargs={"loc": "center left", "bbox_to_anchor": (1, 0.5)},
)
# Out:
# Number of components needed for 99.0% variance: 1
# Shape of input data: (4943, 651)
# Shape of PCA transformed and reduced data: (4943, 1)
# Calculating PHATE...
#   Running PHATE on 4943 observations and 1 variables.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 0.19 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.08 seconds.
#   Calculated graph and diffusion operator in 0.28 seconds.
#   Calculating landmark operator...
#     Calculating SVD...
#     Calculated SVD in 0.91 seconds.
#     Calculating KMeans...
#     Calculated KMeans in 15.91 seconds.
#   Calculated landmark operator in 18.21 seconds.
#   Calculating optimal t...
#     Automatically selected t = 22
#   Calculated optimal t in 6.19 seconds.
#   Calculating diffusion potential...
#   Calculated diffusion potential in 1.31 seconds.
#   Calculating metric MDS...
#   Calculated metric MDS in 6.45 seconds.
# Calculated PHATE in 32.46 seconds.
# Number of clusters: 145
# Average cluster size: 34.09
# <Axes: xlabel='PHATE_0', ylabel='PHATE_1'>

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Cluster Analysis
#
# - `UNIPROT_DATA_FP`: Path to save and access UniProt data with gene descriptions.
# - `STRING_DATA_FP`: Path to save and access STRING data with gene pairs.
# - `CORUM_DATA_FP`: Path to save and access CORUM data with gene complexes.

# %%
UNIPROT_DATA_FP = "config/benchmark_clusters/uniprot_data.tsv"
STRING_DATA_FP = "config/benchmark_clusters/string_data.tsv"
CORUM_DATA_FP = "config/benchmark_clusters/corum_data.tsv"

# %%
# # get and save uniprot data
# uniprot_data = get_uniprot_data()
# Path(UNIPROT_DATA_FP).parent.mkdir(parents=True, exist_ok=True)
# uniprot_data.to_csv(UNIPROT_DATA_FP, sep="\t", index=False)
# display(uniprot_data)

# # get and save string data
# string_data = get_string_data()
# Path(STRING_DATA_FP).parent.mkdir(parents=True, exist_ok=True)
# string_data.to_csv(STRING_DATA_FP, sep="\t", index=False)
# display(string_data)

# # get and save corum data
# corum_data = get_corum_data()
# Path(CORUM_DATA_FP).parent.mkdir(parents=True, exist_ok=True)
# corum_data.to_csv(CORUM_DATA_FP, sep="\t", index=False)
# display(corum_data)

uniprot_data = pd.read_csv(UNIPROT_DATA_FP, sep="\t")
string_data = pd.read_csv(STRING_DATA_FP, sep="\t")
corum_data = pd.read_csv(CORUM_DATA_FP, sep="\t")

# %%
# load cluster data with uniprot annotations
phate_leiden_uniprot = merge_phate_uniprot(phate_leiden_clustering, UNIPROT_DATA_FP)

# create cluster gene table
cluster_gene_table = create_cluster_gene_table(
    phate_leiden_uniprot,
    columns_to_combine=[POPULATION_FEATURE, "STRING"],
)

# analyze differential features
cluster_gene_table, diff_results = analyze_differential_features(
    cluster_gene_table, cleaned_data
)

# process interactions and get enrichment results
cluster_gene_table, global_metrics = process_interactions(
    cluster_gene_table, STRING_DATA_FP, CORUM_DATA_FP
)

# show cluster analysis results
display(cluster_gene_table)
display(global_metrics)
# Out:
# Analyzing 145 clusters...
# Processing cluster 145/145 (#144)
#      cluster_number                                      gene_symbol_0  \
# 0                 0  ADAMTSL5, AKAP8L, ANAPC11, ARL1, C11orf68, CAP...
# 1                 1  ABHD11, ADSS2, ASPM, ATP23, BCL2L2, BMS1, BRD8...
# 2                 2  ATP6AP1, ATP6AP2, ATP6V1F, BAZ1B, BOLA2&BOLA2B...
# 3                 3  AATF, ADGRB2, ADSL, ANAPC4, AP3B1, ATP2B4, ATR...
# 4                 4  AGBL5, ANKRD35, ARPC4-TTLL3, ATIC, ATP2A2, ATP...
# ..              ...                                                ...
# 140             140  ALG11, ALG6, BBS9, CLDN19, FAM98B, KNTC1, MRPS...
# 141             141  BIRC6, CHGB, COX6C, EPB41L3, FUS, PRAMEF20, RI...
# 142             142  BAP1, GOT2, HNRNPCL1, SAMD4B, SETDB1, SLC35G3,...
# 143             143                                              ZNF24
# 144             144                                           CDKN2AIP
#
#                                                 STRING  gene_number  \
# 0    9606.ENSP00000206542, 9606.ENSP00000215794, 96...           58
# 1    9606.ENSP00000164305, 9606.ENSP00000220429, 96...           57
# 2    9606.ENSP00000234170, 9606.ENSP00000254803, 96...           56
# 3    9606.ENSP00000216832, 9606.ENSP00000255194, 96...           52
# 4    9606.ENSP00000221494, 9606.ENSP00000224950, 96...           51
# ..                                                 ...          ...
# 140  9606.ENSP00000081029, 9606.ENSP00000242067, 96...           12
# 141  9606.ENSP00000231238, 9606.ENSP00000254108, 96...           11
# 142  9606.ENSP00000245206, 9606.ENSP00000271640, 96...           11
# 143                               9606.ENSP00000382015            1
# 144                               9606.ENSP00000427108            1
#
#                                               top_5_up  \
# 0    cytoplasm_DAPI_weighted_hu_moments_3, nucleus_...
# 1    cytoplasm_DAPI_pftas_49, cell_CENPA_weighted_h...
# 2    nucleus_zernike_6_0, cell_DAPI_weighted_hu_mom...
# 3    nucleus_DAPI_upper_quartile, cytoplasm_DAPI_pf...
# 4    cell_DAPI_pftas_28, nucleus_CENPA_pftas_32, cy...
# ..                                                 ...
# 140  cytoplasm_angle_between_neighbors, nucleus_ang...
# 141  cell_DAPI_center_mass_c, cytoplasm_lstsq_slope...
# 142  cell_DAPI_weighted_hu_moments_3, cytoplasm_DAP...
# 143  nucleus_DAPI_mean, nucleus_CENPA_mean, nucleus...
# 144  nucleus_DAPI_mean, nucleus_CENPA_mean, nucleus...
#
#                                             top_5_down  total_string_pairs  \
# 0    nucleus_DAPI_pftas_40, nucleus_DAPI_pftas_29, ...                1653
# 1    nucleus_CENPA_mean_frac_2, nucleus_zernike_8_2...                1431
# 2    cytoplasm_zernike_7_5, cytoplasm_DAPI_max_loca...                1326
# 3    cytoplasm_DAPI_weighted_hu_moments_3, cytoplas...                1225
# 4    cytoplasm_DAPI_weighted_hu_moments_3, nucleus_...                1326
# ..                                                 ...                 ...
# 140  cytoplasm_DAPI_weighted_hu_moments_3, cytoplas...                  78
# 141  cytoplasm_DAPI_weighted_hu_moments_3, nucleus_...                  45
# 142  nucleus_DAPI_pftas_28, nucleus_DAPI_pftas_22, ...                  66
# 143  nucleus_DAPI_mean, nucleus_CENPA_mean, nucleus...                   0
# 144  nucleus_DAPI_mean, nucleus_CENPA_mean, nucleus...                   0
#
#      string_validated_pairs  string_validation_ratio  \
# 0                         4                 0.002420
# 1                         3                 0.002096
# 2                         5                 0.003771
# 3                         0                 0.000000
# 4                         1                 0.000754
# ..                      ...                      ...
# 140                       1                 0.012821
# 141                       0                 0.000000
# 142                       0                 0.000000
# 143                       0                 0.000000
# 144                       0                 0.000000
#
#                               enriched_corum_complexes  num_enriched_complexes
# 0    p54(nrb)-PSF-matrin3 complex, Toposome, E2F-6 ...                      12
# 1    TFIID complex, COG complex, URI complex (Uncon...                      27
# 2    Ku antigen-NARG1 complex, Cohesin-SA1 complex,...                      39
# 3    Anaphase-promoting complex, Anaphase-promoting...                      48
# 4    Nup 107-160 subcomplex, TFIID complex, PA700-2...                      26
# ..                                                 ...                     ...
# 140  28S ribosomal subunit, mitochondrial, tRNA Spl...                       5
# 141  Large Drosha complex, DGCR8 multiprotein compl...                       7
# 142  ZNF304-corepressor complex, CDYL-CAF1-MCM comp...                       3
# 143                                                                          0
# 144                                                                          0
#
# [145 rows x 11 columns]
#                           metric          value
# 0                   num_clusters     145.000000
# 1        string_global_precision       0.002346
# 2           string_global_recall       0.001716
# 3               string_global_f1       0.001982
# 4   string_total_predicted_pairs   85681.000000
# 5   string_total_reference_pairs  117118.000000
# 6     string_total_correct_pairs     201.000000
# 7                corum_precision       0.002236
# 8                   corum_recall       0.004204
# 9                       corum_f1       0.002920
# 10     corum_total_cluster_pairs   90330.000000
# 11     corum_total_complex_pairs   48049.000000
# 12          corum_matching_pairs     202.000000
# 13        num_enriched_complexes  102871.000000

# %% [markdown]
# ## Add cluster parameters to config file

# %%
# Add cluster section
config["cluster"] = {
    "channel_combos": CHANNEL_COMBOS,
    "dataset_types": DATASET_TYPES,
    "min_cell_cutoffs": MIN_CELL_CUTOFFS,
    "correlation_threshold": CORRELATION_THRESHOLD,
    "variance_threshold": VARIANCE_THRESHOLD,
    "min_unique_values": MIN_UNIQUE_VALUES,
    "cum_var_threshold": CUM_VAR_THRESHOLD,
    "leiden_resolution": LEIDEN_RESOLUTION,
    "uniprot_data_fp": UNIPROT_DATA_FP,
    "string_data_fp": STRING_DATA_FP,
    "corum_data_fp": CORUM_DATA_FP,
}

# Write the updated configuration
with open(CONFIG_FILE_PATH, "w") as config_file:
    # Write the introductory comments
    config_file.write(CONFIG_FILE_HEADER)

    # Dump the updated YAML structure, keeping markdown comments for sections
    yaml.dump(config, config_file, default_flow_style=False)
